# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data_Train.csv')
df
# Out:
#            ID  Asst_Reg GGGrade Experience       Validation  Yearly Income  \
# 0       95074    421802      II     >10yrs            Vfied      633600.00
# 1      134131   3964312      IV       7yrs  Source Verified       85483.20
# 2       92602   4247560     III       <1yr  Source Verified       79200.00
# 3       22591    197179     III       <1yr            Vfied       61600.00
# 4      125060   4646684       V       2yrs  Source Verified       68053.92
# ...       ...       ...     ...        ...              ...            ...
# 87495  120884   4535984      II     >10yrs        Not Vfied       75680.00
# 87496   33259   2624710      IV       3yrs  Source Verified       90423.52
# 87497  102153   5966919      II     >10yrs  Source Verified       91520.00
# 87498  115343   2630667     III       1yrs  Source Verified       61600.00
# 87499  104968   6637289     III       2yrs            Vfied            NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87500 entries, 0 to 87499
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   87500 non-null  int64
#  1   Asst_Reg             87500 non-null  int64
#  2   GGGrade              87500 non-null  object
#  3   Experience           87500 non-null  object
#  4   Validation           87500 non-null  object
#  5   Yearly Income        81925 non-null  float64
#  6   Home Status          87500 non-null  object
#  7   Unpaid 2 years       87500 non-null  int64
#  8   Already Defaulted    87500 non-null  int64
#  9   Designation          86086 non-null  object
#  10  Debt to Income       84011 non-null  float64
#  11  Postal Code          86111 non-null  float64
#  12  Lend Amount          87500 non-null  float64
#  13  Deprecatory Records  87500 non-null  int64
#  14  Interest Charged     87500 non-null  float64
# ...

# %%
for feature in df.columns:
    print("--",feature,"--")
    print (df[feature].value_counts(normalize=True))
    print("\n\n")
# Out:
# -- ID --
# 95074     0.000011
# 102140    0.000011
# 102258    0.000011
# 80480     0.000011
# 39012     0.000011
#             ...
# 79773     0.000011
# 40215     0.000011
# 61647     0.000011
# 76276     0.000011
# 104968    0.000011
# Name: ID, Length: 87500, dtype: float64
#
#
#
# -- Asst_Reg --
# 6238431    0.000034
# 7054989    0.000034
# 6428230    0.000034
# 4738693    0.000034
# 1195917    0.000034
#              ...
# 6084772    0.000011
# 391671     0.000011
# 6095924    0.000011
# 4728725    0.000011
# 6637289    0.000011
# Name: Asst_Reg, Length: 83966, dtype: float64
#
#
#
# -- GGGrade --
# II     0.285326
# III    0.281737
# I      0.161954
# IV     0.158480
# V      0.081760
# VI     0.025051
# VII    0.005691
# Name: GGGrade, dtype: float64
#
#
#
# -- Experience --
# >10yrs    0.352560
# 2yrs      0.092160
# 3yrs      0.084000
# <1yr      0.082389
# 1yrs      0.066891
# 5yrs      0.064263
# 4yrs      0.060846
# 7yrs      0.054423
# 8yrs      0.052617
# ...

# %%
df['GGGrade'].replace('VII','VI',inplace=True)
df['GGGrade'].replace('VI','V',inplace=True)

# %%
df['GGGrade'].value_counts(normalize=True)
# Out:
# II     0.285326
# III    0.281737
# I      0.161954
# IV     0.158480
# V      0.112503
# Name: GGGrade, dtype: float64

# %%
df['Experience'].value_counts(normalize=True)
# Out:
# >10yrs    0.352560
# 2yrs      0.092160
# 3yrs      0.084000
# <1yr      0.082389
# 1yrs      0.066891
# 5yrs      0.064263
# 4yrs      0.060846
# 7yrs      0.054423
# 8yrs      0.052617
# 6yrs      0.048629
# 9yrs      0.041223
# Name: Experience, dtype: float64

# %%
df['Experience'].replace('<1yr','1-3',inplace=True)
df['Experience'].replace('1yrs','1-3',inplace=True)
df['Experience'].replace('2yrs','1-3',inplace=True)
df['Experience'].replace('3yrs','1-3',inplace=True)

# %%
df['Experience'].replace('4yrs','4-9',inplace=True)
df['Experience'].replace('5yrs','4-9',inplace=True)
df['Experience'].replace('6yrs','4-9',inplace=True)
df['Experience'].replace('7yrs','4-9',inplace=True)
df['Experience'].replace('8yrs','4-9',inplace=True)
df['Experience'].replace('9yrs','4-9',inplace=True)

# %%
df['Validation'].value_counts(normalize=True)
# Out:
# Source Verified    0.394331
# Vfied              0.304480
# Not Vfied          0.301189
# Name: Validation, dtype: float64

# %%
df['Validation'].replace('Source Verified','Vfied',inplace=True)

# %%
df['Home Status'].value_counts(normalize=True)
# Out:
# MOR??AGE    0.504686
# REN?        0.399017
# OWN         0.096183
# OTHER       0.000069
# NONE        0.000046
# Name: Home Status, dtype: float64

# %%
df['Home Status'].replace('NONE','MOR??AGE',inplace=True)
df['Home Status'].replace('OTHER','MOR??AGE',inplace=True)

# %%
df['Unpaid 2 years'] = df['Unpaid 2 years'].astype(str)
df
# Out:
#            ID  Asst_Reg GGGrade Experience Validation  Yearly Income  \
# 0       95074    421802      II     >10yrs      Vfied      633600.00
# 1      134131   3964312      IV        4-9      Vfied       85483.20
# 2       92602   4247560     III        1-3      Vfied       79200.00
# 3       22591    197179     III        1-3      Vfied       61600.00
# 4      125060   4646684       V        1-3      Vfied       68053.92
# ...       ...       ...     ...        ...        ...            ...
# 87495  120884   4535984      II     >10yrs  Not Vfied       75680.00
# 87496   33259   2624710      IV        1-3      Vfied       90423.52
# 87497  102153   5966919      II     >10yrs      Vfied       91520.00
# 87498  115343   2630667     III        1-3      Vfied       61600.00
# 87499  104968   6637289     III        1-3      Vfied            NaN
#
#       Home Status Unpaid 2 years  Already Defaulted            Designation  \
# ...

# %%
df['Unpaid 2 years'].value_counts(normalize=True)
# Out:
# 0     0.797337
# 1     0.132617
# 2     0.041806
# 3     0.014560
# 4     0.006457
# 5     0.003143
# 6     0.001783
# 7     0.000766
# 8     0.000491
# 9     0.000297
# 10    0.000251
# 12    0.000171
# 11    0.000149
# 18    0.000046
# 14    0.000046
# 13    0.000034
# 16    0.000023
# 15    0.000023
# Name: Unpaid 2 years, dtype: float64

# %%
for i in range(df.shape[0]):
    if (df.loc[i,'Unpaid 2 years'] != '0') and (df.loc[i,'Unpaid 2 years'] != '1') and (df.loc[i,'Unpaid 2 years'] != '2'):
        df.loc[i,'Unpaid 2 years'] = 3

# %%
df['Already Defaulted'] = df['Already Defaulted'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87500 entries, 0 to 87499
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   87500 non-null  int64
#  1   Asst_Reg             87500 non-null  int64
#  2   GGGrade              87500 non-null  object
#  3   Experience           87500 non-null  object
#  4   Validation           87500 non-null  object
#  5   Yearly Income        81925 non-null  float64
#  6   Home Status          87500 non-null  object
#  7   Unpaid 2 years       87500 non-null  object
#  8   Already Defaulted    87500 non-null  object
#  9   Designation          86086 non-null  object
#  10  Debt to Income       84011 non-null  float64
#  11  Postal Code          86111 non-null  float64
#  12  Lend Amount          87500 non-null  float64
#  13  Deprecatory Records  87500 non-null  int64
#  14  Interest Charged     87500 non-null  float64
# ...

# %%
df['Already Defaulted'].value_counts(normalize=True)
# Out:
# 0    0.994686
# 1    0.005017
# 2    0.000251
# 6    0.000011
# 5    0.000011
# 4    0.000011
# 3    0.000011
# Name: Already Defaulted, dtype: float64

# %%
for i in range(df.shape[0]):
    if df.loc[i,'Already Defaulted'] != '0':
        df.loc[i,'Already Defaulted'] = '1'

# %%
df['Designation'].value_counts(normalize=True)
# Out:
# School Teacher                 0.018412
# Super Lead                     0.015357
# Nurse                          0.008631
# RN                             0.007504
# Owner                          0.007237
#                                  ...
# B.R. Amon and Sons             0.000012
# Medical record technician      0.000012
# Executive Field Assistant      0.000012
# Speech language pathologist    0.000012
# Outside sales rep              0.000012
# Name: Designation, Length: 40354, dtype: float64

# %%
df['Postal Code'] = df['Postal Code'].astype(str)
df['Postal Code'].value_counts(normalize=True)
# Out:
# nan        0.015874
# 75000.0    0.011166
# 94500.0    0.010571
# 11200.0    0.010320
# 60600.0    0.009623
#              ...
# 4300.0     0.000011
# 90100.0    0.000011
# 50000.0    0.000011
# 96500.0    0.000011
# 83800.0    0.000011
# Name: Postal Code, Length: 866, dtype: float64

# %%
df['Deprecatory Records'] = df['Deprecatory Records'].astype(str)
df['Deprecatory Records'].value_counts(normalize=True)
# Out:
# 0     0.843737
# 1     0.129760
# 2     0.016926
# 3     0.005314
# 4     0.002206
# 5     0.000971
# 6     0.000446
# 7     0.000274
# 8     0.000160
# 10    0.000080
# 9     0.000034
# 16    0.000023
# 12    0.000011
# 86    0.000011
# 11    0.000011
# 13    0.000011
# 22    0.000011
# 15    0.000011
# Name: Deprecatory Records, dtype: float64

# %%
for i in range(df.shape[0]):
    if (df.loc[i,'Deprecatory Records'] != '0') and (df.loc[i,'Deprecatory Records'] != '1'):
        df.loc[i,'Deprecatory Records'] = '2'

# %%
df['Inquiries'] = df['Inquiries'].astype(str)
df['Inquiries'].value_counts(normalize=True)
# Out:
# 0    0.569749
# 1    0.269726
# 2    0.103314
# 3    0.040423
# 4    0.012069
# 5    0.003600
# 6    0.001109
# 8    0.000011
# Name: Inquiries, dtype: float64

# %%
for i in range(df.shape[0]):
    if (df.loc[i,'Inquiries'] != '0') and (df.loc[i,'Inquiries'] != '1') and (df.loc[i,'Inquiries'] != '2'):
        df.loc[i,'Inquiries'] = '3'

# %%
df['Reason'].value_counts(normalize=True)
# Out:
# debt  consolidation    0.600674
# credit  card           0.241166
# home  improvement      0.055840
# other                  0.043131
# major  purchase        0.017280
# medical                0.009383
# small  business        0.008583
# car                    0.008114
# moving                 0.005749
# vacation               0.004846
# house                  0.003554
# wedding                0.001246
# renewable  energy      0.000434
# Name: Reason, dtype: float64

# %%
for i in range(df.shape[0]):
    if (df.loc[i,'Inquiries'] != 'debt  consolidation') and (df.loc[i,'Inquiries'] != 'credit  card') and (df.loc[i,'Inquiries'] != 'home  improvement') and (df.loc[i,'Inquiries'] != 'other'):
        df.loc[i,'Inquiries'] = 'other-1'

# %%
df.to_csv('milestone1.csv',index=0)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('milestone1.csv')
df
# Out:
#            ID  Asst_Reg GGGrade Experience Validation  Yearly Income  \
# 0       95074    421802      II     >10yrs      Vfied      633600.00
# 1      134131   3964312      IV        4-9      Vfied       85483.20
# 2       92602   4247560     III        1-3      Vfied       79200.00
# 3       22591    197179     III        1-3      Vfied       61600.00
# 4      125060   4646684       V        1-3      Vfied       68053.92
# ...       ...       ...     ...        ...        ...            ...
# 87495  120884   4535984      II     >10yrs  Not Vfied       75680.00
# 87496   33259   2624710      IV        1-3      Vfied       90423.52
# 87497  102153   5966919      II     >10yrs      Vfied       91520.00
# 87498  115343   2630667     III        1-3      Vfied       61600.00
# 87499  104968   6637289     III        1-3      Vfied            NaN
#
#       Home Status  Unpaid 2 years  Already Defaulted            Designation  \
# ...

# %%
df.drop(['Designation','Asst_Reg','Postal Code','Claim Type'],axis=1,inplace=True)

# %%
df.drop(['Account Open', 'State', 'Sub GGGrade'],axis=1,inplace=True)

# %%
df.drop('ID',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# GGGrade                   0
# Experience                0
# Validation                0
# Yearly Income          5575
# Home Status               0
# Unpaid 2 years            0
# Already Defaulted         0
# Debt to Income         3489
# Lend Amount               0
# Deprecatory Records       0
# Interest Charged          0
# Usage Rate                0
# Inquiries                 0
# Present Balance           0
# Gross Collection          0
# File Status               0
# Total Unpaid CL        4186
# Duration                  0
# Unpaid Amount          4852
# Reason                    0
# Due Fee                   0
# Loan/No Loan              0
# dtype: int64

# %%
df['Loan/No Loan'].value_counts()
# Out:
# 0    70988
# 1    16512
# Name: Loan/No Loan, dtype: int64

# %%
df['Loan/No Loan'].value_counts(normalize=True)
# Out:
# 0    0.811291
# 1    0.188709
# Name: Loan/No Loan, dtype: float64

# %%
df['Yearly Income'].fillna(df['Yearly Income'].mean(),inplace=True)
df['Debt to Income'].fillna(df['Debt to Income'].mean(),inplace=True)
df['Total Unpaid CL'].fillna(df['Total Unpaid CL'].mean(),inplace=True)
df['Unpaid Amount'].fillna(df['Unpaid Amount'].mean(),inplace=True)

#df['Postal Code'].fillna(df['Postal Code'].value_counts().index[0],inplace=True)
#df['Designation'].fillna(df['Designation'].value_counts().index[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# GGGrade                0
# Experience             0
# Validation             0
# Yearly Income          0
# Home Status            0
# Unpaid 2 years         0
# Already Defaulted      0
# Debt to Income         0
# Lend Amount            0
# Deprecatory Records    0
# Interest Charged       0
# Usage Rate             0
# Inquiries              0
# Present Balance        0
# Gross Collection       0
# File Status            0
# Total Unpaid CL        0
# Duration               0
# Unpaid Amount          0
# Reason                 0
# Due Fee                0
# Loan/No Loan           0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#       GGGrade Experience Validation  Yearly Income Home Status  \
# 0          II     >10yrs      Vfied   633600.00000    MOR??AGE
# 1          IV        4-9      Vfied    85483.20000        REN?
# 2         III        1-3      Vfied    79200.00000        REN?
# 3         III        1-3      Vfied    61600.00000        REN?
# 4           V        1-3      Vfied    68053.92000        REN?
# ...       ...        ...        ...            ...         ...
# 87495      II     >10yrs  Not Vfied    75680.00000        REN?
# 87496      IV        1-3      Vfied    90423.52000        REN?
# 87497      II     >10yrs      Vfied    91520.00000    MOR??AGE
# 87498     III        1-3      Vfied    61600.00000    MOR??AGE
# 87499     III        1-3      Vfied   134859.62978        REN?
#
#        Unpaid 2 years  Already Defaulted  Debt to Income  Lend Amount  \
# 0                   0                  0         12.5496     42023.25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87500 entries, 0 to 87499
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GGGrade              87500 non-null  object
#  1   Experience           87500 non-null  object
#  2   Validation           87500 non-null  object
#  3   Yearly Income        87500 non-null  float64
#  4   Home Status          87500 non-null  object
#  5   Unpaid 2 years       87500 non-null  int64
#  6   Already Defaulted    87500 non-null  int64
#  7   Debt to Income       87500 non-null  float64
#  8   Lend Amount          87500 non-null  float64
#  9   Deprecatory Records  87500 non-null  int64
#  10  Interest Charged     87500 non-null  float64
#  11  Usage Rate           87500 non-null  float64
#  12  Inquiries            87500 non-null  object
#  13  Present Balance      87500 non-null  float64
#  14  Gross Collection     87500 non-null  float64
# ...

# %%
X = df.drop('Loan/No Loan', axis=1)

y = df['Loan/No Loan']

# %%
X = pd.get_dummies(X,drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled = scaler.fit_transform(X)
X=pd.DataFrame(scaled,columns=X.columns,index=X.index)

# %%
 from sklearn import svm
clf = svm.SVC(class_weight='balanced')
model=clf.fit(X,y)

# %%
df = pd.read_csv('Data_Test.csv')
df
# Out:
#            ID  Asst_Reg GGGrade Experience       Validation  Yearly Income  \
# 0      198980   1773284      II       2yrs  Source Verified      140800.00
# 1      167688   5298273      II     >10yrs            Vfied      146080.00
# 2      198768    189781      VI     >10yrs            Vfied      202222.24
# 3      192564   1530906      II     >10yrs            Vfied      105600.00
# 4      151199   4410316     III       4yrs        Not Vfied      151360.00
# ...       ...       ...     ...        ...              ...            ...
# 37495  191405   5774816      IV       4yrs            Vfied      308000.00
# 37496  164868   1423834      IV       8yrs  Source Verified      158400.00
# 37497  163156   1895531       V     >10yrs        Not Vfied       52800.00
# 37498  169610   2168910      VI       9yrs        Not Vfied       52800.00
# 37499  175557   4140268      II     >10yrs  Source Verified      121440.00
#
#       Home Status  Unpaid 2 years  Already Defaulted  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37500 entries, 0 to 37499
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   37500 non-null  int64
#  1   Asst_Reg             37500 non-null  int64
#  2   GGGrade              37500 non-null  object
#  3   Experience           37500 non-null  object
#  4   Validation           37500 non-null  object
#  5   Yearly Income        35075 non-null  float64
#  6   Home Status          37500 non-null  object
#  7   Unpaid 2 years       37500 non-null  int64
#  8   Already Defaulted    37500 non-null  int64
#  9   Designation          36914 non-null  object
#  10  Debt to Income       35989 non-null  float64
#  11  Postal Code          36889 non-null  float64
#  12  Lend Amount          37500 non-null  float64
#  13  Deprecatory Records  37500 non-null  int64
#  14  Interest Charged     37500 non-null  float64
# ...

# %%
df['GGGrade'].replace('VII','VI',inplace=True)
df['GGGrade'].replace('VI','V',inplace=True)

# %%
df['GGGrade'].value_counts(normalize=True)
# Out:
# III    0.284853
# II     0.281040
# I      0.163440
# IV     0.156213
# V      0.114453
# Name: GGGrade, dtype: float64

# %%
df['Experience'].value_counts(normalize=True)
# Out:
# >10yrs    0.350907
# 2yrs      0.090987
# 3yrs      0.083413
# <1yr      0.082720
# 1yrs      0.065147
# 5yrs      0.064320
# 4yrs      0.059707
# 8yrs      0.057173
# 7yrs      0.052507
# 6yrs      0.049520
# 9yrs      0.043600
# Name: Experience, dtype: float64

# %%
df['Experience'].replace('<1yr','1-3',inplace=True)
df['Experience'].replace('1yrs','1-3',inplace=True)
df['Experience'].replace('2yrs','1-3',inplace=True)
df['Experience'].replace('3yrs','1-3',inplace=True)

# %%
df['Experience'].replace('4yrs','4-9',inplace=True)
df['Experience'].replace('5yrs','4-9',inplace=True)
df['Experience'].replace('6yrs','4-9',inplace=True)
df['Experience'].replace('7yrs','4-9',inplace=True)
df['Experience'].replace('8yrs','4-9',inplace=True)
df['Experience'].replace('9yrs','4-9',inplace=True)

# %%
df['Validation'].value_counts(normalize=True)
# Out:
# Source Verified    0.390560
# Not Vfied          0.306347
# Vfied              0.303093
# Name: Validation, dtype: float64

# %%
df['Validation'].replace('Source Verified','Vfied',inplace=True)

# %%
df['Home Status'].value_counts(normalize=True)
# Out:
# MOR??AGE    0.504320
# REN?        0.399787
# OWN         0.095787
# NONE        0.000053
# OTHER       0.000053
# Name: Home Status, dtype: float64

# %%
df['Home Status'].replace('NONE','MOR??AGE',inplace=True)
df['Home Status'].replace('OTHER','MOR??AGE',inplace=True)

# %%
df['Unpaid 2 years'] = df['Unpaid 2 years'].astype(str)
df
# Out:
#            ID  Asst_Reg GGGrade Experience Validation  Yearly Income  \
# 0      198980   1773284      II        1-3      Vfied      140800.00
# 1      167688   5298273      II     >10yrs      Vfied      146080.00
# 2      198768    189781       V     >10yrs      Vfied      202222.24
# 3      192564   1530906      II     >10yrs      Vfied      105600.00
# 4      151199   4410316     III        4-9  Not Vfied      151360.00
# ...       ...       ...     ...        ...        ...            ...
# 37495  191405   5774816      IV        4-9      Vfied      308000.00
# 37496  164868   1423834      IV        4-9      Vfied      158400.00
# 37497  163156   1895531       V     >10yrs  Not Vfied       52800.00
# 37498  169610   2168910       V        4-9  Not Vfied       52800.00
# 37499  175557   4140268      II     >10yrs      Vfied      121440.00
#
#       Home Status Unpaid 2 years  Already Defaulted  \
# 0             OWN              0                  0
# ...

# %%
df['Unpaid 2 years'].value_counts(normalize=True)
# Out:
# 0     0.797760
# 1     0.132427
# 2     0.040027
# 3     0.014453
# 4     0.007307
# 5     0.003307
# 6     0.002187
# 7     0.001147
# 8     0.000613
# 10    0.000213
# 9     0.000213
# 12    0.000107
# 13    0.000053
# 17    0.000053
# 11    0.000053
# 15    0.000027
# 14    0.000027
# 18    0.000027
# Name: Unpaid 2 years, dtype: float64

# %%
for i in range(df.shape[0]):
    if (df.loc[i,'Unpaid 2 years'] != '0') and (df.loc[i,'Unpaid 2 years'] != '1') and (df.loc[i,'Unpaid 2 years'] != '2'):
        df.loc[i,'Unpaid 2 years'] = 3

# %%
df['Already Defaulted'] = df['Already Defaulted'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37500 entries, 0 to 37499
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   37500 non-null  int64
#  1   Asst_Reg             37500 non-null  int64
#  2   GGGrade              37500 non-null  object
#  3   Experience           37500 non-null  object
#  4   Validation           37500 non-null  object
#  5   Yearly Income        35075 non-null  float64
#  6   Home Status          37500 non-null  object
#  7   Unpaid 2 years       37500 non-null  object
#  8   Already Defaulted    37500 non-null  object
#  9   Designation          36914 non-null  object
#  10  Debt to Income       35989 non-null  float64
#  11  Postal Code          36889 non-null  float64
#  12  Lend Amount          37500 non-null  float64
#  13  Deprecatory Records  37500 non-null  int64
#  14  Interest Charged     37500 non-null  float64
# ...

# %%
df['Already Defaulted'].value_counts(normalize=True)
# Out:
# 0    0.995013
# 1    0.004747
# 2    0.000160
# 3    0.000080
# Name: Already Defaulted, dtype: float64

# %%
for i in range(df.shape[0]):
    if df.loc[i,'Already Defaulted'] != '0':
        df.loc[i,'Already Defaulted'] = '1'

# %%
df['Designation'].value_counts(normalize=True)
# Out:
# School Teacher                      0.018042
# Super Lead                          0.016119
# Nurse                               0.009156
# RN                                  0.007585
# Owner                               0.007260
#                                       ...
# License Consultant                  0.000027
# Systems Administrator Supervisor    0.000027
# At. Acct.                           0.000027
# Senior Sales Engineer               0.000027
# ParaEducator                        0.000027
# Name: Designation, Length: 19510, dtype: float64

# %%
df['Postal Code'] = df['Postal Code'].astype(str)
df['Postal Code'].value_counts(normalize=True)
# Out:
# nan        0.016293
# 75000.0    0.011253
# 94500.0    0.010480
# 11200.0    0.009867
# 60600.0    0.009413
#              ...
# 58400.0    0.000027
# 9000.0     0.000027
# 51300.0    0.000027
# 5200.0     0.000027
# 20400.0    0.000027
# Name: Postal Code, Length: 850, dtype: float64

# %%
df['Deprecatory Records'] = df['Deprecatory Records'].astype(str)
df['Deprecatory Records'].value_counts(normalize=True)
# Out:
# 0     0.841707
# 1     0.132853
# 2     0.016933
# 3     0.004880
# 4     0.001840
# 5     0.000853
# 6     0.000480
# 7     0.000187
# 8     0.000080
# 9     0.000053
# 21    0.000027
# 11    0.000027
# 12    0.000027
# 13    0.000027
# 10    0.000027
# Name: Deprecatory Records, dtype: float64

# %%
for i in range(df.shape[0]):
    if (df.loc[i,'Deprecatory Records'] != '0') and (df.loc[i,'Deprecatory Records'] != '1'):
        df.loc[i,'Deprecatory Records'] = '2'

# %%
df['Inquiries'] = df['Inquiries'].astype(str)
df['Inquiries'].value_counts(normalize=True)
# Out:
# 0    0.566640
# 1    0.271920
# 2    0.103067
# 3    0.041040
# 4    0.012213
# 5    0.004107
# 6    0.001013
# Name: Inquiries, dtype: float64

# %%
for i in range(df.shape[0]):
    if (df.loc[i,'Inquiries'] != '0') and (df.loc[i,'Inquiries'] != '1') and (df.loc[i,'Inquiries'] != '2'):
        df.loc[i,'Inquiries'] = '3'

# %%
df['Reason'].value_counts(normalize=True)
# Out:
# debt  consolidation    0.599013
# credit  card           0.241440
# home  improvement      0.057520
# other                  0.045173
# major  purchase        0.016187
# medical                0.008907
# small  business        0.008107
# car                    0.008027
# moving                 0.005840
# vacation               0.004507
# house                  0.003627
# wedding                0.001120
# renewable  energy      0.000533
# Name: Reason, dtype: float64

# %%
for i in range(df.shape[0]):
    if (df.loc[i,'Inquiries'] != 'debt  consolidation') and (df.loc[i,'Inquiries'] != 'credit  card') and (df.loc[i,'Inquiries'] != 'home  improvement') and (df.loc[i,'Inquiries'] != 'other'):
        df.loc[i,'Inquiries'] = 'other-1'

# %%
df.drop(['Designation','Asst_Reg','Postal Code','Claim Type'],axis=1,inplace=True)

# %%
df.drop(['Account Open', 'State', 'Sub GGGrade'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                        0
# GGGrade                   0
# Experience                0
# Validation                0
# Yearly Income          2425
# Home Status               0
# Unpaid 2 years            0
# Already Defaulted         0
# Debt to Income         1511
# Lend Amount               0
# Deprecatory Records       0
# Interest Charged          0
# Usage Rate                0
# Inquiries                 0
# Present Balance           0
# Gross Collection          0
# File Status               0
# Total Unpaid CL        1814
# Duration                  0
# Unpaid Amount          2069
# Reason                    0
# Due Fee                   0
# dtype: int64

# %%
#df['Postal Code'] = df['Postal Code'].astype("object")

# %%
df['Yearly Income'].fillna(df['Yearly Income'].mean(),inplace=True)
df['Debt to Income'].fillna(df['Debt to Income'].mean(),inplace=True)
df['Total Unpaid CL'].fillna(df['Total Unpaid CL'].mean(),inplace=True)
df['Unpaid Amount'].fillna(df['Unpaid Amount'].mean(),inplace=True)

#df['Postal Code'].fillna(df['Postal Code'].value_counts().index[0],inplace=True)
#df['Designation'].fillna(df['Designation'].value_counts().index[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                     0
# GGGrade                0
# Experience             0
# Validation             0
# Yearly Income          0
# Home Status            0
# Unpaid 2 years         0
# Already Defaulted      0
# Debt to Income         0
# Lend Amount            0
# Deprecatory Records    0
# Interest Charged       0
# Usage Rate             0
# Inquiries              0
# Present Balance        0
# Gross Collection       0
# File Status            0
# Total Unpaid CL        0
# Duration               0
# Unpaid Amount          0
# Reason                 0
# Due Fee                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37500 entries, 0 to 37499
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   37500 non-null  int64
#  1   GGGrade              37500 non-null  object
#  2   Experience           37500 non-null  object
#  3   Validation           37500 non-null  object
#  4   Yearly Income        37500 non-null  float64
#  5   Home Status          37500 non-null  object
#  6   Unpaid 2 years       37500 non-null  object
#  7   Already Defaulted    37500 non-null  object
#  8   Debt to Income       37500 non-null  float64
#  9   Lend Amount          37500 non-null  float64
#  10  Deprecatory Records  37500 non-null  object
#  11  Interest Charged     37500 non-null  float64
#  12  Usage Rate           37500 non-null  float64
#  13  Inquiries            37500 non-null  object
#  14  Present Balance      37500 non-null  float64
# ...

# %%
df
# Out:
#            ID GGGrade Experience Validation  Yearly Income Home Status  \
# 0      198980      II        1-3      Vfied      140800.00         OWN
# 1      167688      II     >10yrs      Vfied      146080.00    MOR??AGE
# 2      198768       V     >10yrs      Vfied      202222.24    MOR??AGE
# 3      192564      II     >10yrs      Vfied      105600.00    MOR??AGE
# 4      151199     III        4-9  Not Vfied      151360.00    MOR??AGE
# ...       ...     ...        ...        ...            ...         ...
# 37495  191405      IV        4-9      Vfied      308000.00    MOR??AGE
# 37496  164868      IV        4-9      Vfied      158400.00    MOR??AGE
# 37497  163156       V     >10yrs  Not Vfied       52800.00         OWN
# 37498  169610       V        4-9  Not Vfied       52800.00         OWN
# 37499  175557      II     >10yrs      Vfied      121440.00    MOR??AGE
#
#       Unpaid 2 years Already Defaulted  Debt to Income  Lend Amount  ...  \
# ...

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df['Deprecatory Records'] = 0
df['Already Defaulted'] = 0
df['Unpaid 2 years'] = 0

# %%
df_temp=df.drop(['ID', 'Unpaid 2 years_0', 'Unpaid 2 years_1', 'Unpaid 2 years_2', 'Already Defaulted_1',
                 'Deprecatory Records_1', 'Deprecatory Records_2'],axis=1)
scaled = scaler.transform(df_temp)
df_temp=pd.DataFrame(scaled,columns=df_temp.columns,index=df_temp.index)
df_temp['ID'] = df['ID'].copy()
df=df_temp.copy()
# Out:
# C:\Users\cools\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %%
df['Loan/No Loan'] = model.predict(df.drop('ID',axis=1))
df
# Out:
# C:\Users\cools\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
#        Yearly Income  Debt to Income    Lend Amount  Interest Charged  \
# 0           0.062122       24.409083  246956.175425         -1.599188
# 1           0.117338       41.708650  823187.421970         -1.510758
# 2           0.704453       74.703689  823187.421970         -0.843906
# 3          -0.305986       39.240809  265771.889598         -1.603537
# 4           0.172555       14.809180  348678.630173         -1.262863
# ...              ...             ...            ...               ...
# 37495       1.810636       42.794500  823187.421970         -0.854778
# 37496       0.246176       45.978016  388074.031722         -0.864201
# ...

# %%
df2=df[['ID','Loan/No Loan']]
df2['ID'] = df2['ID'].astype('int64')
df2['Loan/No Loan'] = df2['Loan/No Loan'].astype('int64')
df2
# Out:
# C:\Users\cools\AppData\Local\Temp/ipykernel_7248/3842719934.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['ID'] = df2['ID'].astype('int64')
# C:\Users\cools\AppData\Local\Temp/ipykernel_7248/3842719934.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Loan/No Loan'] = df2['Loan/No Loan'].astype('int64')
#            ID  Loan/No Loan
# 0      198980             0
# 1      167688             0
# 2      198768             0
# 3      192564             0
# ...

# %%
df = pd.read_csv('Data_Test.csv')
df
# Out:
#            ID  Asst_Reg GGGrade Experience       Validation  Yearly Income  \
# 0      198980   1773284      II       2yrs  Source Verified      140800.00
# 1      167688   5298273      II     >10yrs            Vfied      146080.00
# 2      198768    189781      VI     >10yrs            Vfied      202222.24
# 3      192564   1530906      II     >10yrs            Vfied      105600.00
# 4      151199   4410316     III       4yrs        Not Vfied      151360.00
# ...       ...       ...     ...        ...              ...            ...
# 37495  191405   5774816      IV       4yrs            Vfied      308000.00
# 37496  164868   1423834      IV       8yrs  Source Verified      158400.00
# 37497  163156   1895531       V     >10yrs        Not Vfied       52800.00
# 37498  169610   2168910      VI       9yrs        Not Vfied       52800.00
# 37499  175557   4140268      II     >10yrs  Source Verified      121440.00
#
#       Home Status  Unpaid 2 years  Already Defaulted  \
# ...

# %%
df2['ID'] = df['ID']
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37500 entries, 0 to 37499
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            37500 non-null  int64
#  1   Loan/No Loan  37500 non-null  int64
# dtypes: int64(2)
# memory usage: 586.1 KB
# C:\Users\cools\AppData\Local\Temp/ipykernel_7248/2065228058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['ID'] = df['ID']

# %%
df2.to_csv('file_scaled_bal1.csv',index=0)
