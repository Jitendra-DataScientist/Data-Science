# %% [markdown]
# # Problem Statement

# %% [markdown]
# Lending is one of the critical functions of any bank or financial institution. Customers are provided loans across different products (home loan, loan against property etc.) at competitive interest rates for an acceptable tenure. There is always a risk that a customer may default on the loan or may try and repay the loan in advance which leads to financial losses to the business.
#
# There may not be enough data or evidence available from the past which will help the firm to predict the loan default or prepayment and mitigate the above possible risk. However, it does have information about the customer demographics, loan details, EMI transactions etc. which contributes to more than 25-30 features (high-dimension data) related to a customer’s loan account. But due to high dimensions it is difficult to identify any patterns within the data. Unsupervised learning techniques like Principal Component Analysis comes to rescue here to reduce the high dimensionality and help in further analysis and pattern recognition.

# %% [markdown]
# ## About Data

# %% [markdown]
# Data file contains information about the loan transactions done by the customer.
#
# All important details regarding the loan i.e. loan amount, interest rate, outstanding principal, loan to value ratio (Net LTV), tenure, city where the loan was originated etc. has been provided.
#
# Some of the features that correspond to multiple loan transactions (e.g. rate of interest, emi amount, frequency of emi payment etc.) for a loan account are summarized and captured for each loan account.

# %% [markdown]
# ### Import  required libraries

# %%
#!pip install factor_analyzer

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from factor_analyzer import FactorAnalyzer # Perform statistical tests before PCA 
import warnings
warnings.filterwarnings("ignore")
df1 = pd.read_excel('2 Short Term Home Loans Data Dictionary.xlsx')
df1
# Out:
#      #                               Fields  \
# 0    1                         loan_account
# 1    2                                  age
# 2    3                               gender
# 3    4                       marital_status
# 4    5                        qualification
# 5    6                         gross_income
# 6    7                          nettakehome
# 7    8                       balance_tenure
# 8    9                                 city
# 9   10                     completed_tenure
# 10  11                           emi_dueamt
# 11  12                     emi_received_amt
# 12  13                  excess_adjusted_amt
# 13  14                     excess_available
# 14  15                                 foir
# 15  16                             loan_amt
# 16  17                         monthopening
# 17  18                    net_disbursed_amt
# 18  19                              net_ltv
# 19  20                       net_receivable
# 20  21                orignal_interest_rate
# 21  22                        orignal_tenor
# 22  23                outstanding_principal
# 23  24                        paid_interest
# 24  25                       paid_principal
# 25  26                       pre_emi_dueamt
# 26  27                 pre_emi_received_amt
# 27  28                current_interest_rate
# 28  29            current_interest_rate_max
# 29  30            current_interest_rate_min
# 30  31                        current_tenor
# 31  32   diff_current_interest_rate_max_min
# 32  33              diff_emi_amount_max_min
# 33  34  diff_original_current_interest_rate
# 34  35          diff_original_current_tenor
# 35  36                           emi_amount
# 36  37                  last_receipt_amount
# 37  38                       max_emi_amount
# 38  39                       min_emi_amount
# 39  40                      num_emi_changes
# 40  41            num_low_freq_transactions
# 41  42              num_of_emi_transactions
#
#                                           Description Summarized
# 0                              Unique loan account ID          N
# 1                                 Age of the customer          N
# 2                              Gender of the customer          N
# 3                      Marital status of the customer          N
# 4                            Customer's qualification          N
# 5                        Gross income of the customer          N
# 6                       Net take home of the customer          N
# 7                                    Remaining tenure          N
# 8                                 City of origination          N
# 9                                    Completed tenure          N
# 10                                     EMI due amount          N
# 11                          Total EMI received amount          N
# 12                             Excess adjusted amount          N
# 13                                    Excess received          N
# 14  Fixed obligation to income ratio (Value should...          N
# 15                   Loan amount which was sanctioned          N
# 16       Balance Prinicipal at beginning of the month          N
# 17                          Amount that was disbursed          N
# 18  Net Loan to Value ratio (Value ranges from 0-1...          N
# 19  Amount to be received after consdering the EMI...          N
# 20  Original rate of interest on the loan (when th...          N
# 21  Original tenor of the loan (when the loan was ...          N
# 22                       Outstanding principal amount          N
# 23                                      Paid interest          N
# 24                                     Paid principal          N
# 25                    Pre EMI due amount for the loan          N
# 26                         Pre EMI that was received           N
# 27  Current rate of interest on the loan - Interes...          Y
# 28  Maximum value of the current rate of interest ...          Y
# 29  Minimum value of the current rate of interest ...          Y
# 30                          Current tenor of the loan          Y
# 31                           Change in interest rate           Y
# 32  Difference in maximum and minimum EMI amount paid          Y
# 33   Difference in original and current interest rate          Y
# 34          Difference in original and current tenor           Y
# 35                                       Expected EMI          Y
# 36          EMI received from last transaction amount          Y
# 37                        Maximum EMI amount received          Y
# 38                        Minimum EMI amount received          Y
# 39  Number of different values in the EMI amount r...          Y
# 40   Number of transactions done in less than 28 days          Y
# 41     Number of EMI transactions expected in months           Y

# %% [markdown]
# ### Read and view data

# %%
df = pd.read_excel('3 Short Term Home Loans.xlsx')

# %%
df.head()
# Out:
#   loan_account  age gender marital_status qualification  gross_income  \
# 0        LA492   39      F              M            UG  63542.344735
# 1        LA498   51      M              M          GRAD  81130.025032
# 2        LA500   41      M              M            UG  56298.592500
# 3        LA531   42      M              M            UG  74314.142100
# 4        LA552   27      M              S          GRAD  64255.460240
#
#     nettakehome  balance_tenure     city  completed_tenure  ...  \
# 0  63542.344735             111  MADURAI                70  ...
# 1  81130.025032             107  MADURAI                68  ...
# 2  56298.592500              50  MADURAI                70  ...
# 3  74314.142100             110  MADURAI                70  ...
# 4  64255.460240             112  MADURAI                69  ...
#
#    num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 0               11                         10                       73
# 1                3                         11                       73
# 2               13                         10                       73
# 3               13                         17                       72
# 4               14                         10                       71
#
#    orignal_interest_rate  orignal_tenor  outstanding_principal  paid_interest  \
# 0              17.479728            180           9.882910e+05   9.340537e+05
# 1              17.479728            180           1.206218e+06   1.069305e+06
# 2              17.479728            120           7.137100e+05   8.303592e+05
# 3              17.479728            180           1.744746e+06   1.567354e+06
# 4              17.479728            180           1.502039e+06   1.355995e+06
#
#    paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 0   212745.625226    39959.331336          39959.331336
# 1   295078.188194    78774.632736          78774.632736
# 2   487326.621863    37918.629288          37918.629288
# 3   357068.193072    29375.950152          29375.950152
# 4   299516.018579    46048.309200          46048.309200
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (2319, 42)

# %%
df.describe().T
# Out:
#                                       count          mean           std  \
# age                                  2319.0  3.945106e+01  8.982396e+00
# gross_income                         2319.0  8.260822e+04  1.264007e+05
# nettakehome                          2319.0  8.134619e+04  1.268459e+05
# balance_tenure                       2319.0  1.466628e+02  4.513873e+01
# completed_tenure                     2319.0  2.950367e+01  1.349025e+01
# current_interest_rate                2319.0  1.569870e+01  1.872893e+00
# current_interest_rate_max            2319.0  1.578384e+01  1.832462e+00
# current_interest_rate_min            2319.0  1.568473e+01  1.875045e+00
# current_tenor                        2319.0  1.759711e+02  4.224263e+01
# diff_current_interest_rate_max_min   2319.0  1.042883e-01  5.631563e-01
# diff_emi_amount_max_min              2319.0  5.635589e+04  1.959045e+05
# diff_original_current_interest_rate  2319.0  6.943758e-02  4.787330e-01
# diff_original_current_tenor          2319.0  4.896507e+00  2.337057e+01
# emi_amount                           2319.0  1.801202e+04  1.237318e+04
# emi_dueamt                           2319.0  1.191197e+06  1.064387e+06
# emi_received_amt                     2319.0  1.132347e+06  9.800945e+05
# excess_adjusted_amt                  2319.0  1.319928e+05  5.867103e+05
# excess_available                     2319.0  1.865469e+05  7.175169e+05
# foir                                 2319.0  4.262294e-01  1.463204e-01
# last_receipt_amount                  2319.0  4.114352e+04  1.748835e+05
# loan_amt                             2319.0  2.194991e+06  1.349637e+06
# max_emi_amount                       2319.0  5.807497e+04  1.960221e+05
# min_emi_amount                       2319.0  1.723590e+03  5.332765e+03
# monthopening                         2319.0  2.035442e+06  1.286849e+06
# net_disbursed_amt                    2319.0  2.189517e+06  1.349531e+06
# net_ltv                              2319.0  5.157001e+01  1.875792e+01
# net_receivable                       2319.0  4.978290e+03  5.257671e+05
# num_emi_changes                      2319.0  5.356188e+00  3.809970e+00
# num_low_freq_transactions            2319.0  4.567486e+00  3.610644e+00
# num_of_emi_transactions              2319.0  3.215610e+01  1.325195e+01
# orignal_interest_rate                2319.0  1.576814e+01  1.814290e+00
# orignal_tenor                        2319.0  1.808676e+02  3.585916e+01
# outstanding_principal                2319.0  1.949442e+06  1.289269e+06
# paid_interest                        2319.0  6.538977e+05  5.553356e+05
# paid_principal                       2319.0  2.389494e+05  4.546814e+05
# pre_emi_dueamt                       2319.0  5.630330e+04  1.176218e+05
# pre_emi_received_amt                 2319.0  5.562086e+04  1.155979e+05
#
#                                               min           25%           50%  \
# age                                  1.800000e+01  3.200000e+01  3.900000e+01
# gross_income                         0.000000e+00  4.189591e+04  6.184963e+04
# nettakehome                          0.000000e+00  4.109947e+04  6.050222e+04
# balance_tenure                       0.000000e+00  1.290000e+02  1.500000e+02
# completed_tenure                     0.000000e+00  2.200000e+01  2.800000e+01
# current_interest_rate                1.107466e+01  1.404621e+01  1.591904e+01
# current_interest_rate_max            1.107466e+01  1.435835e+01  1.591904e+01
# current_interest_rate_min            1.107466e+01  1.404621e+01  1.591904e+01
# current_tenor                        1.000000e+01  1.730000e+02  1.800000e+02
# diff_current_interest_rate_max_min   0.000000e+00  0.000000e+00  0.000000e+00
# diff_emi_amount_max_min              0.000000e+00  1.029850e+04  1.735000e+04
# diff_original_current_interest_rate -1.248552e+00  0.000000e+00  0.000000e+00
# diff_original_current_tenor         -9.400000e+01  0.000000e+00  0.000000e+00
# emi_amount                           1.437000e+01  9.727000e+03  1.465000e+04
# emi_dueamt                           0.000000e+00  5.517018e+05  8.936884e+05
# emi_received_amt                     0.000000e+00  5.325923e+05  8.662891e+05
# excess_adjusted_amt                  0.000000e+00  0.000000e+00  0.000000e+00
# excess_available                     0.000000e+00  0.000000e+00  1.727088e+02
# foir                                 0.000000e+00  3.400000e-01  4.200000e-01
# last_receipt_amount                  2.000000e+00  9.316000e+03  1.440500e+04
# loan_amt                             1.756516e+05  1.238569e+06  1.801555e+06
# max_emi_amount                       5.620000e+02  1.157300e+04  1.897500e+04
# min_emi_amount                       9.000000e-02  1.150000e+02  1.150000e+02
# monthopening                         1.514357e+05  1.135780e+06  1.688189e+06
# net_disbursed_amt                    1.756516e+05  1.231063e+06  1.801555e+06
# net_ltv                              5.220000e+00  3.680000e+01  5.207000e+01
# net_receivable                      -7.133502e+06 -3.259933e+02 -4.417104e-01
# num_emi_changes                      0.000000e+00  3.000000e+00  4.000000e+00
# num_low_freq_transactions            0.000000e+00  2.000000e+00  3.000000e+00
# num_of_emi_transactions              0.000000e+00  2.400000e+01  3.100000e+01
# orignal_interest_rate                1.107466e+01  1.435835e+01  1.591904e+01
# orignal_tenor                        6.000000e+01  1.800000e+02  1.800000e+02
# outstanding_principal                0.000000e+00  1.065798e+06  1.606862e+06
# paid_interest                        0.000000e+00  3.083669e+05  5.082382e+05
# paid_principal                       0.000000e+00  6.463679e+04  1.159271e+05
# pre_emi_dueamt                       0.000000e+00  5.852663e+03  1.687113e+04
# pre_emi_received_amt                 0.000000e+00  5.848246e+03  1.687113e+04
#
#                                               75%           max
# age                                  4.600000e+01  6.500000e+01
# gross_income                         9.118946e+04  4.261664e+06
# nettakehome                          9.046402e+04  4.261664e+06
# balance_tenure                       1.670000e+02  3.070000e+02
# completed_tenure                     3.700000e+01  7.000000e+01
# current_interest_rate                1.747973e+01  1.997683e+01
# current_interest_rate_max            1.747973e+01  1.997683e+01
# current_interest_rate_min            1.747973e+01  1.997683e+01
# current_tenor                        1.810000e+02  3.160000e+02
# diff_current_interest_rate_max_min   0.000000e+00  1.201107e+01
# diff_emi_amount_max_min              2.860478e+04  3.229383e+06
# diff_original_current_interest_rate  0.000000e+00  5.618484e+00
# diff_original_current_tenor          0.000000e+00  2.280000e+02
# emi_amount                           2.264000e+04  1.200000e+05
# emi_dueamt                           1.453225e+06  9.853225e+06
# emi_received_amt                     1.397185e+06  9.853225e+06
# excess_adjusted_amt                  1.091124e+03  1.020263e+07
# excess_available                     3.881751e+03  1.021953e+07
# foir                                 4.900000e-01  1.001000e+00
# last_receipt_amount                  2.307700e+04  3.229945e+06
# loan_amt                             2.818683e+06  1.089366e+07
# max_emi_amount                       2.967650e+04  3.229945e+06
# min_emi_amount                       5.730000e+02  8.400100e+04
# monthopening                         2.620309e+06  1.080242e+07
# net_disbursed_amt                    2.800199e+06  1.089366e+07
# net_ltv                              6.889000e+01  8.439000e+01
# net_receivable                       0.000000e+00  8.252080e+06
# num_emi_changes                      7.000000e+00  2.700000e+01
# num_low_freq_transactions            6.000000e+00  2.100000e+01
# num_of_emi_transactions              4.000000e+01  7.300000e+01
# orignal_interest_rate                1.747973e+01  1.997683e+01
# orignal_tenor                        1.800000e+02  2.400000e+02
# outstanding_principal                2.546081e+06  1.080242e+07
# paid_interest                        8.067100e+05  5.588191e+06
# paid_principal                       2.208857e+05  7.458322e+06
# pre_emi_dueamt                       5.423541e+04  1.624202e+06
# pre_emi_received_amt                 5.423541e+04  1.585701e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2319 entries, 0 to 2318
# Data columns (total 42 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   loan_account                         2319 non-null   object
#  1   age                                  2319 non-null   int64
#  2   gender                               2319 non-null   object
#  3   marital_status                       2319 non-null   object
#  4   qualification                        2319 non-null   object
#  5   gross_income                         2319 non-null   float64
#  6   nettakehome                          2319 non-null   float64
#  7   balance_tenure                       2319 non-null   int64
#  8   city                                 2319 non-null   object
#  9   completed_tenure                     2319 non-null   int64
#  10  current_interest_rate                2319 non-null   float64
#  11  current_interest_rate_max            2319 non-null   float64
#  12  current_interest_rate_min            2319 non-null   float64
#  13  current_tenor                        2319 non-null   int64
#  14  diff_current_interest_rate_max_min   2319 non-null   float64
#  15  diff_emi_amount_max_min              2319 non-null   float64
#  16  diff_original_current_interest_rate  2319 non-null   float64
#  17  diff_original_current_tenor          2319 non-null   int64
#  18  emi_amount                           2319 non-null   float64
#  19  emi_dueamt                           2319 non-null   float64
#  20  emi_received_amt                     2319 non-null   float64
#  21  excess_adjusted_amt                  2319 non-null   float64
#  22  excess_available                     2319 non-null   float64
#  23  foir                                 2319 non-null   float64
#  24  last_receipt_amount                  2319 non-null   float64
#  25  loan_amt                             2319 non-null   float64
#  26  max_emi_amount                       2319 non-null   float64
#  27  min_emi_amount                       2319 non-null   float64
#  28  monthopening                         2319 non-null   float64
#  29  net_disbursed_amt                    2319 non-null   float64
#  30  net_ltv                              2319 non-null   float64
#  31  net_receivable                       2319 non-null   float64
#  32  num_emi_changes                      2319 non-null   int64
#  33  num_low_freq_transactions            2319 non-null   int64
#  34  num_of_emi_transactions              2319 non-null   int64
#  35  orignal_interest_rate                2319 non-null   float64
#  36  orignal_tenor                        2319 non-null   int64
#  37  outstanding_principal                2319 non-null   float64
#  38  paid_interest                        2319 non-null   float64
#  39  paid_principal                       2319 non-null   float64
#  40  pre_emi_dueamt                       2319 non-null   float64
#  41  pre_emi_received_amt                 2319 non-null   float64
# dtypes: float64(28), int64(9), object(5)
# memory usage: 761.0+ KB

# %%
df.city.value_counts()
# Out:
# MUMBAI             586
# HYDERABAD          268
# AHMEDABAD          165
# CHENNAI            164
# MADURAI            157
# COIMBATORE         156
# SURAT              136
# ERODE               85
# PUNE                78
# TIRUCHIRAPPALLI     78
# KARUR               65
# TUTICORIN           64
# TIRUPUR             63
# WARANGAL            56
# NAMAKKAL            56
# VISHAKHAPATNAM      45
# BANGALORE           45
# Hyd                 31
# Mum                 21
# Name: city, dtype: int64

# %%
df.gender.value_counts()
# Out:
# M    1994
# F     325
# Name: gender, dtype: int64

# %%
df.marital_status.value_counts()
# Out:
# M    2086
# S     233
# Name: marital_status, dtype: int64

# %%
df.qualification.value_counts()
# Out:
# UG          1548
# GRAD         409
# POSTGRAD     181
# OTHERS       150
# PRF           18
# ENG            6
# MAT            5
# DOCTRATE       2
# Name: qualification, dtype: int64

# %% [markdown]
# #### Observations:
#
# - Data consists of 2319 customer loan transactions with 42 features
#
# - Fields *‘diff_current_interest_rate_max_min’, ‘diff_original_current_interest_rate’, ‘diff_original_current_tenor’* have atleast 75% of the values as 0
#
# - Field *'excess_adjusted_amt'* has atleast 50% of values as 0
#
# - *'gross_income'* & *'nettakehome'* have minimum values as 0. Needs to be cleaned
#
# - There are no missing values in the data
#
# - We have 5 categorical fields *'gender', 'marital status', 'city' and 'qualification'*. *'city'* field needs cleanup.
#
# - Very few observations available for customers with *ENG, MAT, DOCTRATE* qualification

# %% [markdown]
# ### Data Cleanup

# %%
df.city.replace(to_replace='Mum',value='MUMBAI',inplace=True)
df.city.replace(to_replace='Hyd',value='HYDERABAD',inplace=True)
df.city.value_counts()
# Out:
# MUMBAI             607
# HYDERABAD          299
# AHMEDABAD          165
# CHENNAI            164
# MADURAI            157
# COIMBATORE         156
# SURAT              136
# ERODE               85
# PUNE                78
# TIRUCHIRAPPALLI     78
# KARUR               65
# TUTICORIN           64
# TIRUPUR             63
# WARANGAL            56
# NAMAKKAL            56
# BANGALORE           45
# VISHAKHAPATNAM      45
# Name: city, dtype: int64

# %%
print('% of records with 0 value in diff_current_interest_rate_max_min field: {:.2%}'.format((df[df.diff_current_interest_rate_max_min == 0].shape[0])/df.shape[0]))
print('# of records with 0 value in diff_original_current_interest_rate field: {:.2%}'.format((df[df.diff_original_current_interest_rate == 0].shape[0])/df.shape[0]))
print('# of records with 0 value in diff_original_current_tenor field: {:.2%}'.format((df[df.diff_original_current_tenor == 0].shape[0])/df.shape[0]))
print('# of records with 0 value in excess_adjusted_amt field: {:.2%}'.format((df[df.excess_adjusted_amt == 0].shape[0])/df.shape[0]))
# Out:
# % of records with 0 value in diff_current_interest_rate_max_min field: 95.30%
# # of records with 0 value in diff_original_current_interest_rate field: 96.03%
# # of records with 0 value in diff_original_current_tenor field: 72.49%
# # of records with 0 value in excess_adjusted_amt field: 67.96%

# %%
df.drop(['diff_current_interest_rate_max_min','diff_original_current_interest_rate','diff_original_current_tenor','excess_adjusted_amt'], axis=1, inplace=True)

# %%
df[df.gross_income==0]
# Out:
#      loan_account  age gender marital_status qualification  gross_income  \
# 106         LA928   29      F              M          GRAD           0.0
# 616        LA2297   54      F              M            UG           0.0
# 640        LA2348   46      M              M        OTHERS           0.0
# 1198       LA3410   35      M              M          GRAD           0.0
# 2315       LA5726   34      M              M            UG           0.0
#
#       nettakehome  balance_tenure        city  completed_tenure  ...  \
# 106           0.0             159  COIMBATORE                21  ...
# 616           0.0              87    NAMAKKAL                45  ...
# 640           0.0             138      MUMBAI                42  ...
# 1198          0.0             153      MUMBAI                28  ...
# 2315          0.0             240      MUMBAI                 0  ...
#
#       num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 106                 1                          1                       21
# 616                 3                          4                       46
# 640                 5                          4                       43
# 1198                4                          4                       35
# 2315                7                          8                       18
#
#       orignal_interest_rate  orignal_tenor  outstanding_principal  \
# 106               17.479728            180           8.944886e+05
# 616               17.479728            132           1.217339e+06
# 640               17.479728            180           6.839979e+05
# 1198              14.670486            180           2.328519e+06
# 2315              14.358348            240           1.280237e+06
#
#       paid_interest  paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 106   228711.906059    36314.844106     6923.810520           6923.810520
# 616   730542.546646   283956.588908    12884.692368          12884.692368
# 640   361987.939409    66650.027041    12884.692368          12884.692368
# 1198  783168.969620   163632.234425   177258.383520         177258.383520
# 2315  130587.212571        0.000000   316114.464864         192106.478616
#
# [5 rows x 38 columns]

# %%
df[df.nettakehome==0]
# Out:
#      loan_account  age gender marital_status qualification   gross_income  \
# 8           LA570   44      M              M          GRAD   90077.748000
# 106         LA928   29      F              M          GRAD       0.000000
# 307        LA1496   25      F              S          GRAD   75759.889955
# 395        LA1783   44      M              M        OTHERS   15012.958000
# 521        LA2100   34      M              S            UG   40228.722257
# 545        LA2147   47      M              M        OTHERS  105090.706000
# 616        LA2297   54      F              M            UG       0.000000
# 640        LA2348   46      M              M        OTHERS       0.000000
# 662        LA2392   60      M              M          GRAD   89787.997911
# 664        LA2395   48      F              M            UG   30660.964123
# 1059       LA3144   41      M              M            UG   30025.916000
# 1198       LA3410   35      M              M          GRAD       0.000000
# 1201       LA3416   55      M              M      POSTGRAD  108608.242059
# 1219       LA3443   48      F              M        OTHERS   69052.100321
# 1252       LA3505   60      M              M          GRAD  150129.580000
# 1491       LA3962   44      F              M        OTHERS   67558.311000
# 1713       LA4424   38      M              M          GRAD   48910.715868
# 1844       LA4677   36      M              M            UG   77016.474540
# 1883       LA4748   33      M              M            UG   77992.316810
# 1905       LA4798   37      F              M            UG   51320.295627
# 2076       LA5154   46      M              M            UG   75323.012878
# 2090       LA5182   27      M              S            UG   42723.875876
# 2315       LA5726   34      M              M            UG       0.000000
#
#       nettakehome  balance_tenure        city  completed_tenure  ...  \
# 8             0.0               0     CHENNAI                49  ...
# 106           0.0             159  COIMBATORE                21  ...
# 307           0.0             186     CHENNAI                54  ...
# 395           0.0             138   HYDERABAD                42  ...
# 521           0.0              85   TUTICORIN                40  ...
# 545           0.0             120     CHENNAI                45  ...
# 616           0.0              87    NAMAKKAL                45  ...
# 640           0.0             138      MUMBAI                42  ...
# 662           0.0              53     MADURAI                44  ...
# 664           0.0             196   HYDERABAD                44  ...
# 1059          0.0             202  COIMBATORE                38  ...
# 1198          0.0             153      MUMBAI                28  ...
# 1201          0.0             130      MUMBAI                26  ...
# 1219          0.0             156     MADURAI                24  ...
# 1252          0.0              97       KARUR                35  ...
# 1491          0.0              76     MADURAI                22  ...
# 1713          0.0             218      MUMBAI                23  ...
# 1844          0.0             152       SURAT                28  ...
# 1883          0.0             152     TIRUPUR                28  ...
# 1905          0.0             154   HYDERABAD                26  ...
# 2076          0.0              95      MUMBAI                25  ...
# 2090          0.0             156   HYDERABAD                24  ...
# 2315          0.0             240      MUMBAI                 0  ...
#
#       num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 8                   2                          6                       50
# 106                 1                          1                       21
# 307                 2                          1                       55
# 395                 9                          6                       50
# 521                15                         11                       46
# 545                 3                          2                       46
# 616                 3                          4                       46
# 640                 5                          4                       43
# 662                 4                          2                       45
# 664                18                         10                       45
# 1059                4                          4                       39
# 1198                4                          4                       35
# 1201                9                          6                       27
# 1219                2                          1                       25
# 1252                8                          8                       35
# 1491                4                          4                       23
# 1713                8                          8                       28
# 1844                2                          2                       29
# 1883                2                          2                       29
# 1905                3                          2                       27
# 2076                4                          2                       26
# 2090                4                          3                       25
# 2315                7                          8                       18
#
#       orignal_interest_rate  orignal_tenor  outstanding_principal  \
# 8                 17.479728            180           0.000000e+00
# 106               17.479728            180           8.944886e+05
# 307               17.479728            240           3.396424e+06
# 395               17.479728            180           2.081138e+06
# 521               17.479728            156           8.974986e+05
# 545               17.479728            180           2.635998e+06
# 616               17.479728            132           1.217339e+06
# 640               17.479728            180           6.839979e+05
# 662               14.982624             96           1.195590e+06
# 664               14.358348            240           1.084249e+06
# 1059              15.606900            240           1.108872e+06
# 1198              14.670486            180           2.328519e+06
# 1201              13.734072            156           4.827318e+06
# 1219              14.046210            180           2.476117e+06
# 1252              15.919038            132           3.366726e+06
# 1491              16.231176            180           3.241012e+05
# 1713              14.046210            240           1.968928e+06
# 1844              12.011070            180           1.245672e+06
# 1883              15.919038            180           2.256994e+06
# 1905              14.358348            180           2.535791e+06
# 2076              15.606900            120           9.007775e+05
# 2090              15.606900            180           9.253522e+05
# 2315              14.358348            240           1.280237e+06
#
#       paid_interest  paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 8      1.213050e+06    3.753240e+06    10737.979824          10737.979824
# 106    2.287119e+05    3.631484e+04     6923.810520           6923.810520
# 307    2.233865e+06    2.066864e+05    30919.728000          30919.728000
# 395    1.138929e+06    1.708054e+05   282875.757264         282875.757264
# 521    5.893742e+05    3.035380e+05   106719.441192         106719.441192
# 545    1.503699e+06    4.416587e+05    26412.073368          26412.073368
# 616    7.305425e+05    2.839566e+05    12884.692368          12884.692368
# 640    3.619879e+05    6.665003e+04    12884.692368          12884.692368
# 662    6.926213e+05    6.254819e+05    23227.341384          23227.341384
# 664    4.744590e+05    6.574324e+04    14053.016376          14053.016376
# 1059   4.331989e+05    5.463215e+04     2972.710992           2972.710992
# 1198   7.831690e+05    1.636322e+05   177258.383520         177258.383520
# 1201   1.173501e+06    4.272177e+05    21257.313000          21257.313000
# 1219   5.976569e+05    1.511505e+05    32611.478832          32611.478832
# 1252   1.300142e+06    5.366427e+05    16270.402584          16270.402584
# 1491   3.923156e+05    2.153037e+06     6581.484960           6581.484960
# 1713   5.090819e+05    5.782091e+04   114433.913328         114433.913328
# 1844   2.945032e+05    1.054946e+05     3186.940536           3186.940536
# 1883   6.999942e+05    1.450792e+05     7509.076800           7509.076800
# 1905   6.775663e+05    1.665417e+05    34287.769800          34287.769800
# 2076   5.683200e+05    1.351166e+06    20705.175000          20705.175000
# 2090   2.422581e+05    5.049008e+04     5982.967368           5982.967368
# 2315   1.305872e+05    0.000000e+00   316114.464864         192106.478616
#
# [23 rows x 38 columns]

# %%
df.gross_income.replace(to_replace=0, value=df.gross_income.median(),inplace=True)
df.nettakehome.replace(to_replace=0, value=df.nettakehome.median(),inplace=True)

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Univariate Analysis

# %% [markdown]
# Let us define a function **'univariateAnalysis_numeric'** to display information as part of univariate analysis of numeric variables. The function will accept coulmn name and number of bins as arguments.
#
# The function will display the statistical description of the the numeric variable, histogram or distplot to view the distribution and the box plot to view 5 point summary and outliers if any.

# %%
def univariateAnalysis_numeric(column,nbins):
    print("Description of " + column)
    print("----------------------------------------------------------------------------")
    print(df[column].describe(),end=' ')
    
    
    plt.figure()
    print("Distribution of " + column)
    print("----------------------------------------------------------------------------")
    sns.distplot(df[column], kde=False, color='g',bins=nbins);
    plt.show()
    
    plt.figure()
    print("BoxPlot of " + column)
    print("----------------------------------------------------------------------------")
    ax = sns.boxplot(x=df[column])
    plt.show()

# %%
univariateAnalysis_numeric('age',20)
# Out:
# Description of age
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       39.451056
# std         8.982396
# min        18.000000
# 25%        32.000000
# 50%        39.000000
# 75%        46.000000
# max        65.000000
# Name: age, dtype: float64 Distribution of age
# ----------------------------------------------------------------------------
# BoxPlot of age
# ----------------------------------------------------------------------------

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
lstnumericcolumns = list(df_num.columns.values)
len(lstnumericcolumns)
# Out:
# 33

# %%
df_num.head()
# Out:
#    age  gross_income   nettakehome  balance_tenure  completed_tenure  \
# 0   39  63542.344735  63542.344735             111                70
# 1   51  81130.025032  81130.025032             107                68
# 2   41  56298.592500  56298.592500              50                70
# 3   42  74314.142100  74314.142100             110                70
# 4   27  64255.460240  64255.460240             112                69
#
#    current_interest_rate  current_interest_rate_max  \
# 0              17.479728                  17.479728
# 1              14.982624                  17.479728
# 2              17.479728                  17.479728
# 3              17.479728                  17.479728
# 4              17.479728                  17.479728
#
#    current_interest_rate_min  current_tenor  diff_emi_amount_max_min  ...  \
# 0                  17.479728            181                 11557.38  ...
# 1                  14.982624            175                 13523.09  ...
# 2                  17.479728            120                 13608.59  ...
# 3                  17.479728            180                 38412.99  ...
# 4                  17.479728            181                 32346.11  ...
#
#    num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 0               11                         10                       73
# 1                3                         11                       73
# 2               13                         10                       73
# 3               13                         17                       72
# 4               14                         10                       71
#
#    orignal_interest_rate  orignal_tenor  outstanding_principal  paid_interest  \
# 0              17.479728            180           9.882910e+05   9.340537e+05
# 1              17.479728            180           1.206218e+06   1.069305e+06
# 2              17.479728            120           7.137100e+05   8.303592e+05
# 3              17.479728            180           1.744746e+06   1.567354e+06
# 4              17.479728            180           1.502039e+06   1.355995e+06
#
#    paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 0   212745.625226    39959.331336          39959.331336
# 1   295078.188194    78774.632736          78774.632736
# 2   487326.621863    37918.629288          37918.629288
# 3   357068.193072    29375.950152          29375.950152
# 4   299516.018579    46048.309200          46048.309200
#
# [5 rows x 33 columns]

# %%
for x in lstnumericcolumns:
    univariateAnalysis_numeric(x,20)
# Out:
# Description of age
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       39.451056
# std         8.982396
# min        18.000000
# 25%        32.000000
# 50%        39.000000
# 75%        46.000000
# max        65.000000
# Name: age, dtype: float64 Distribution of age
# ----------------------------------------------------------------------------
# BoxPlot of age
# ----------------------------------------------------------------------------
# Description of gross_income
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     8.274157e+04
# std      1.263460e+05
# min      1.250579e+01
# 25%      4.203628e+04
# 50%      6.184963e+04
# 75%      9.118946e+04
# max      4.261664e+06
# Name: gross_income, dtype: float64 Distribution of gross_income
# ----------------------------------------------------------------------------
# BoxPlot of gross_income
# ----------------------------------------------------------------------------
# Description of nettakehome
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     8.194625e+04
# std      1.266025e+05
# min      1.246076e-01
# 25%      4.198749e+04
# 50%      6.050222e+04
# 75%      9.046402e+04
# max      4.261664e+06
# Name: nettakehome, dtype: float64 Distribution of nettakehome
# ----------------------------------------------------------------------------
# BoxPlot of nettakehome
# ----------------------------------------------------------------------------
# Description of balance_tenure
# ----------------------------------------------------------------------------
# count    2319.000000
# mean      146.662786
# std        45.138729
# min         0.000000
# 25%       129.000000
# 50%       150.000000
# 75%       167.000000
# max       307.000000
# Name: balance_tenure, dtype: float64 Distribution of balance_tenure
# ----------------------------------------------------------------------------
# BoxPlot of balance_tenure
# ----------------------------------------------------------------------------
# Description of completed_tenure
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       29.503665
# std        13.490253
# min         0.000000
# 25%        22.000000
# 50%        28.000000
# 75%        37.000000
# max        70.000000
# Name: completed_tenure, dtype: float64 Distribution of completed_tenure
# ----------------------------------------------------------------------------
# BoxPlot of completed_tenure
# ----------------------------------------------------------------------------
# Description of current_interest_rate
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       15.698703
# std         1.872893
# min        11.074656
# 25%        14.046210
# 50%        15.919038
# 75%        17.479728
# max        19.976832
# Name: current_interest_rate, dtype: float64 Distribution of current_interest_rate
# ----------------------------------------------------------------------------
# BoxPlot of current_interest_rate
# ----------------------------------------------------------------------------
# Description of current_interest_rate_max
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       15.783840
# std         1.832462
# min        11.074656
# 25%        14.358348
# 50%        15.919038
# 75%        17.479728
# max        19.976832
# Name: current_interest_rate_max, dtype: float64 Distribution of current_interest_rate_max
# ----------------------------------------------------------------------------
# BoxPlot of current_interest_rate_max
# ----------------------------------------------------------------------------
# Description of current_interest_rate_min
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       15.684731
# std         1.875045
# min        11.074656
# 25%        14.046210
# 50%        15.919038
# 75%        17.479728
# max        19.976832
# Name: current_interest_rate_min, dtype: float64 Distribution of current_interest_rate_min
# ----------------------------------------------------------------------------
# BoxPlot of current_interest_rate_min
# ----------------------------------------------------------------------------
# Description of current_tenor
# ----------------------------------------------------------------------------
# count    2319.000000
# mean      175.971108
# std        42.242628
# min        10.000000
# 25%       173.000000
# 50%       180.000000
# 75%       181.000000
# max       316.000000
# Name: current_tenor, dtype: float64 Distribution of current_tenor
# ----------------------------------------------------------------------------
# BoxPlot of current_tenor
# ----------------------------------------------------------------------------
# Description of diff_emi_amount_max_min
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     5.635589e+04
# std      1.959045e+05
# min      0.000000e+00
# 25%      1.029850e+04
# 50%      1.735000e+04
# 75%      2.860478e+04
# max      3.229383e+06
# Name: diff_emi_amount_max_min, dtype: float64 Distribution of diff_emi_amount_max_min
# ----------------------------------------------------------------------------
# BoxPlot of diff_emi_amount_max_min
# ----------------------------------------------------------------------------
# Description of emi_amount
# ----------------------------------------------------------------------------
# count      2319.000000
# mean      18012.023109
# std       12373.175124
# min          14.370000
# 25%        9727.000000
# 50%       14650.000000
# 75%       22640.000000
# max      120000.000000
# Name: emi_amount, dtype: float64 Distribution of emi_amount
# ----------------------------------------------------------------------------
# BoxPlot of emi_amount
# ----------------------------------------------------------------------------
# Description of emi_dueamt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     1.191197e+06
# std      1.064387e+06
# min      0.000000e+00
# 25%      5.517018e+05
# 50%      8.936884e+05
# 75%      1.453225e+06
# max      9.853225e+06
# Name: emi_dueamt, dtype: float64 Distribution of emi_dueamt
# ----------------------------------------------------------------------------
# BoxPlot of emi_dueamt
# ----------------------------------------------------------------------------
# Description of emi_received_amt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     1.132347e+06
# std      9.800945e+05
# min      0.000000e+00
# 25%      5.325923e+05
# 50%      8.662891e+05
# 75%      1.397185e+06
# max      9.853225e+06
# Name: emi_received_amt, dtype: float64 Distribution of emi_received_amt
# ----------------------------------------------------------------------------
# BoxPlot of emi_received_amt
# ----------------------------------------------------------------------------
# Description of excess_available
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     1.865469e+05
# std      7.175169e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.727088e+02
# 75%      3.881751e+03
# max      1.021953e+07
# Name: excess_available, dtype: float64 Distribution of excess_available
# ----------------------------------------------------------------------------
# BoxPlot of excess_available
# ----------------------------------------------------------------------------
# Description of foir
# ----------------------------------------------------------------------------
# count    2319.000000
# mean        0.426229
# std         0.146320
# min         0.000000
# 25%         0.340000
# 50%         0.420000
# 75%         0.490000
# max         1.001000
# Name: foir, dtype: float64 Distribution of foir
# ----------------------------------------------------------------------------
# BoxPlot of foir
# ----------------------------------------------------------------------------
# Description of last_receipt_amount
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     4.114352e+04
# std      1.748835e+05
# min      2.000000e+00
# 25%      9.316000e+03
# 50%      1.440500e+04
# 75%      2.307700e+04
# max      3.229945e+06
# Name: last_receipt_amount, dtype: float64 Distribution of last_receipt_amount
# ----------------------------------------------------------------------------
# BoxPlot of last_receipt_amount
# ----------------------------------------------------------------------------
# Description of loan_amt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     2.194991e+06
# std      1.349637e+06
# min      1.756516e+05
# 25%      1.238569e+06
# 50%      1.801555e+06
# 75%      2.818683e+06
# max      1.089366e+07
# Name: loan_amt, dtype: float64 Distribution of loan_amt
# ----------------------------------------------------------------------------
# BoxPlot of loan_amt
# ----------------------------------------------------------------------------
# Description of max_emi_amount
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     5.807497e+04
# std      1.960221e+05
# min      5.620000e+02
# 25%      1.157300e+04
# 50%      1.897500e+04
# 75%      2.967650e+04
# max      3.229945e+06
# Name: max_emi_amount, dtype: float64 Distribution of max_emi_amount
# ----------------------------------------------------------------------------
# BoxPlot of max_emi_amount
# ----------------------------------------------------------------------------
# Description of min_emi_amount
# ----------------------------------------------------------------------------
# count     2319.000000
# mean      1723.590298
# std       5332.764547
# min          0.090000
# 25%        115.000000
# 50%        115.000000
# 75%        573.000000
# max      84001.000000
# Name: min_emi_amount, dtype: float64 Distribution of min_emi_amount
# ----------------------------------------------------------------------------
# BoxPlot of min_emi_amount
# ----------------------------------------------------------------------------
# Description of monthopening
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     2.035442e+06
# std      1.286849e+06
# min      1.514357e+05
# 25%      1.135780e+06
# 50%      1.688189e+06
# 75%      2.620309e+06
# max      1.080242e+07
# Name: monthopening, dtype: float64 Distribution of monthopening
# ----------------------------------------------------------------------------
# BoxPlot of monthopening
# ----------------------------------------------------------------------------
# Description of net_disbursed_amt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     2.189517e+06
# std      1.349531e+06
# min      1.756516e+05
# 25%      1.231063e+06
# 50%      1.801555e+06
# 75%      2.800199e+06
# max      1.089366e+07
# Name: net_disbursed_amt, dtype: float64 Distribution of net_disbursed_amt
# ----------------------------------------------------------------------------
# BoxPlot of net_disbursed_amt
# ----------------------------------------------------------------------------
# Description of net_ltv
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       51.570013
# std        18.757921
# min         5.220000
# 25%        36.800000
# 50%        52.070000
# 75%        68.890000
# max        84.390000
# Name: net_ltv, dtype: float64 Distribution of net_ltv
# ----------------------------------------------------------------------------
# BoxPlot of net_ltv
# ----------------------------------------------------------------------------
# Description of net_receivable
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     4.978290e+03
# std      5.257671e+05
# min     -7.133502e+06
# 25%     -3.259933e+02
# 50%     -4.417104e-01
# 75%      0.000000e+00
# max      8.252080e+06
# Name: net_receivable, dtype: float64 Distribution of net_receivable
# ----------------------------------------------------------------------------
# BoxPlot of net_receivable
# ----------------------------------------------------------------------------
# Description of num_emi_changes
# ----------------------------------------------------------------------------
# count    2319.000000
# mean        5.356188
# std         3.809970
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         7.000000
# max        27.000000
# Name: num_emi_changes, dtype: float64 Distribution of num_emi_changes
# ----------------------------------------------------------------------------
# BoxPlot of num_emi_changes
# ----------------------------------------------------------------------------
# Description of num_low_freq_transactions
# ----------------------------------------------------------------------------
# count    2319.000000
# mean        4.567486
# std         3.610644
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        21.000000
# Name: num_low_freq_transactions, dtype: float64 Distribution of num_low_freq_transactions
# ----------------------------------------------------------------------------
# BoxPlot of num_low_freq_transactions
# ----------------------------------------------------------------------------
# Description of num_of_emi_transactions
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       32.156102
# std        13.251947
# min         0.000000
# 25%        24.000000
# 50%        31.000000
# 75%        40.000000
# max        73.000000
# Name: num_of_emi_transactions, dtype: float64 Distribution of num_of_emi_transactions
# ----------------------------------------------------------------------------
# BoxPlot of num_of_emi_transactions
# ----------------------------------------------------------------------------
# Description of orignal_interest_rate
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       15.768140
# std         1.814290
# min        11.074656
# 25%        14.358348
# 50%        15.919038
# 75%        17.479728
# max        19.976832
# Name: orignal_interest_rate, dtype: float64 Distribution of orignal_interest_rate
# ----------------------------------------------------------------------------
# BoxPlot of orignal_interest_rate
# ----------------------------------------------------------------------------
# Description of orignal_tenor
# ----------------------------------------------------------------------------
# count    2319.000000
# mean      180.867615
# std        35.859160
# min        60.000000
# 25%       180.000000
# 50%       180.000000
# 75%       180.000000
# max       240.000000
# Name: orignal_tenor, dtype: float64 Distribution of orignal_tenor
# ----------------------------------------------------------------------------
# BoxPlot of orignal_tenor
# ----------------------------------------------------------------------------
# Description of outstanding_principal
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     1.949442e+06
# std      1.289269e+06
# min      0.000000e+00
# 25%      1.065798e+06
# 50%      1.606862e+06
# 75%      2.546081e+06
# max      1.080242e+07
# Name: outstanding_principal, dtype: float64 Distribution of outstanding_principal
# ----------------------------------------------------------------------------
# BoxPlot of outstanding_principal
# ----------------------------------------------------------------------------
# Description of paid_interest
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     6.538977e+05
# std      5.553356e+05
# min      0.000000e+00
# 25%      3.083669e+05
# 50%      5.082382e+05
# 75%      8.067100e+05
# max      5.588191e+06
# Name: paid_interest, dtype: float64 Distribution of paid_interest
# ----------------------------------------------------------------------------
# BoxPlot of paid_interest
# ----------------------------------------------------------------------------
# Description of paid_principal
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     2.389494e+05
# std      4.546814e+05
# min      0.000000e+00
# 25%      6.463679e+04
# 50%      1.159271e+05
# 75%      2.208857e+05
# max      7.458322e+06
# Name: paid_principal, dtype: float64 Distribution of paid_principal
# ----------------------------------------------------------------------------
# BoxPlot of paid_principal
# ----------------------------------------------------------------------------
# Description of pre_emi_dueamt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     5.630330e+04
# std      1.176218e+05
# min      0.000000e+00
# 25%      5.852663e+03
# 50%      1.687113e+04
# 75%      5.423541e+04
# max      1.624202e+06
# Name: pre_emi_dueamt, dtype: float64 Distribution of pre_emi_dueamt
# ----------------------------------------------------------------------------
# BoxPlot of pre_emi_dueamt
# ----------------------------------------------------------------------------
# Description of pre_emi_received_amt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     5.562086e+04
# std      1.155979e+05
# min      0.000000e+00
# 25%      5.848246e+03
# 50%      1.687113e+04
# 75%      5.423541e+04
# max      1.585701e+06
# Name: pre_emi_received_amt, dtype: float64 Distribution of pre_emi_received_amt
# ----------------------------------------------------------------------------
# BoxPlot of pre_emi_received_amt
# ----------------------------------------------------------------------------

# %% [markdown]
# #### Observations
#
# - There are 33 numeric fields in the data
#
# - Customer age ranges from 18 years to 65 years
#
# - Only few customers have gross income more than 30L
#
# - Current interest rate ranges from 11.07% to 19.97% with an average of 16%
#
# - balance_tenure =0 (loans closed). Check outstanding_principal for these loans
#
# - Average EMI amount being paid is around 18012
#
# - Net Receivable of atleast 75% of customers is negative
#
# - Average foir is 0.42
#
# - Loan amount ranges from 175652 to max of 10893660
#
# - Outliers to be treated

# %%
# Closed loans
df[df.balance_tenure==0]
# Out:
#    loan_account  age gender marital_status qualification  gross_income  \
# 8         LA570   44      M              M          GRAD     90077.748
# 25        LA661   37      M              M        OTHERS    112597.185
#
#      nettakehome  balance_tenure        city  completed_tenure  ...  \
# 8    60502.22074               0     CHENNAI                49  ...
# 25  112597.18500               0  COIMBATORE                56  ...
#
#     num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 8                 2                          6                       50
# 25                1                          2                       61
#
#     orignal_interest_rate  orignal_tenor  outstanding_principal  \
# 8               17.479728            180                    0.0
# 25              17.479728            180                    0.0
#
#     paid_interest  paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 8    1.213050e+06    3.753240e+06    10737.979824          10737.979824
# 25   2.141698e+06    4.018367e+06   243530.403384         243530.403384
#
# [2 rows x 38 columns]

# %% [markdown]
# #### Observation
#
# From above records looks like there are customers who are making advance payments to pay off their loan earlier.
#
# num_low_freq_transactions maybe a field that will help us find these customers

# %%
df.num_low_freq_transactions.describe()
# Out:
# count    2319.000000
# mean        4.567486
# std         3.610644
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        21.000000
# Name: num_low_freq_transactions, dtype: float64

# %%
# Probable customers who are paying off their loans earlier
df[df.num_low_freq_transactions > 6]
# Out:
#      loan_account  age gender marital_status qualification  gross_income  \
# 0           LA492   39      F              M            UG  63542.344735
# 1           LA498   51      M              M          GRAD  81130.025032
# 2           LA500   41      M              M            UG  56298.592500
# 3           LA531   42      M              M            UG  74314.142100
# 4           LA552   27      M              S          GRAD  64255.460240
# ...           ...  ...    ...            ...           ...           ...
# 2293       LA5669   32      M              M            UG  40122.505579
# 2301       LA5697   44      M              M          GRAD  82314.051991
# 2303       LA5699   35      M              M           MAT  74407.477660
# 2308       LA5709   53      M              M            UG  73053.053628
# 2315       LA5726   34      M              M            UG  61849.633721
#
#        nettakehome  balance_tenure      city  completed_tenure  ...  \
# 0     63542.344735             111   MADURAI                70  ...
# 1     81130.025032             107   MADURAI                68  ...
# 2     56298.592500              50   MADURAI                70  ...
# 3     74314.142100             110   MADURAI                70  ...
# 4     64255.460240             112   MADURAI                69  ...
# ...            ...             ...       ...               ...  ...
# 2293  40122.505579             220    MUMBAI                20  ...
# 2301  82314.047487             240    MUMBAI                 0  ...
# 2303  74407.477660             223    MUMBAI                17  ...
# 2308  73053.053628             187  NAMAKKAL                17  ...
# 2315  60502.220740             240    MUMBAI                 0  ...
#
#       num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 0                  11                         10                       73
# 1                   3                         11                       73
# 2                  13                         10                       73
# 3                  13                         17                       72
# 4                  14                         10                       71
# ...               ...                        ...                      ...
# 2293               13                          7                       20
# 2301                4                          8                       18
# 2303                7                          8                       22
# 2308                9                          9                       22
# 2315                7                          8                       18
#
#       orignal_interest_rate  orignal_tenor  outstanding_principal  \
# 0                 17.479728            180           9.882910e+05
# 1                 17.479728            180           1.206218e+06
# 2                 17.479728            120           7.137100e+05
# 3                 17.479728            180           1.744746e+06
# 4                 17.479728            180           1.502039e+06
# ...                     ...            ...                    ...
# 2293              14.358348            240           2.180859e+06
# 2301              14.358348            240           1.524213e+06
# 2303              14.046210            240           2.753524e+06
# 2308              16.231176            204           2.488135e+06
# 2315              14.358348            240           1.280237e+06
#
#       paid_interest  paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 0      9.340537e+05   212745.625226    39959.331336          39959.331336
# 1      1.069305e+06   295078.188194    78774.632736          78774.632736
# 2      8.303592e+05   487326.621863    37918.629288          37918.629288
# 3      1.567354e+06   357068.193072    29375.950152          29375.950152
# 4      1.355995e+06   299516.018579    46048.309200          46048.309200
# ...             ...             ...             ...                   ...
# 2293   3.936277e+05    47058.116851     5236.476792           5236.476792
# 2301   7.913330e+04        0.000000   376421.185776         116412.775920
# 2303   5.205503e+05    53899.521812   151519.918512         151519.918512
# 2308   5.596275e+05    64067.798265   139688.705448         139688.705448
# 2315   1.305872e+05        0.000000   316114.464864         192106.478616
#
# [535 rows x 38 columns]

# %% [markdown]
# #### Observation
#
# From above results we see that just *'num_low_freq_transactions'* may not be a feature driving advance closure. Other features like *'interest rate changes', 'emi_amount', 'pre_emi_recieved_amt', 'outstanding_principal'* are also contributing.
#
# It is difficult to consider 33 numeric dimensions to analyze this behavior.
# Hence, PCA can help to reduce dimensions, help in further analysis and derive patterns

# %% [markdown]
# Let us define a function **'univariateAnalysis_category'** to display information as part of univariate analysis of categorical variables.
#
# The function should display the frequency of all the levels within the field and display a frequency plot

# %%
def univariateAnalysis_category(cat_column):
    print("Details of " + cat_column)
    print("----------------------------------------------------------------")
    print(df_cat[cat_column].value_counts())
    plt.figure()
    df_cat[cat_column].value_counts().plot.bar(title="Frequency Distribution of " + cat_column)
    plt.show()
    print("       ")

# %%
df_cat = df.select_dtypes(include = ['object'])
lstcatcolumns = list(df_cat.columns.values)
lstcatcolumns
# Out:
# ['loan_account', 'gender', 'marital_status', 'qualification', 'city']

# %%
lstcatcolumns.remove('loan_account')

# %%
for x in lstcatcolumns:
    univariateAnalysis_category(x)
# Out:
# Details of gender
# ----------------------------------------------------------------
# M    1994
# F     325
# Name: gender, dtype: int64
#
# Details of marital_status
# ----------------------------------------------------------------
# M    2086
# S     233
# Name: marital_status, dtype: int64
#
# Details of qualification
# ----------------------------------------------------------------
# UG          1548
# GRAD         409
# POSTGRAD     181
# OTHERS       150
# PRF           18
# ENG            6
# MAT            5
# DOCTRATE       2
# Name: qualification, dtype: int64
#
# Details of city
# ----------------------------------------------------------------
# MUMBAI             607
# HYDERABAD          299
# AHMEDABAD          165
# CHENNAI            164
# MADURAI            157
# COIMBATORE         156
# SURAT              136
# ERODE               85
# PUNE                78
# TIRUCHIRAPPALLI     78
# KARUR               65
# TUTICORIN           64
# TIRUPUR             63
# WARANGAL            56
# NAMAKKAL            56
# BANGALORE           45
# VISHAKHAPATNAM      45
# Name: city, dtype: int64

# %% [markdown]
# #### Bivariate Analysis

# %%
corr = df_num.corr(method='pearson')

# %%
mask = np.triu(np.ones_like(corr, dtype=np.bool)) # code explained in 'Concept of masking(during session).ipynb' file
mask
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [False,  True,  True, ...,  True,  True,  True],
#        [False, False,  True, ...,  True,  True,  True],
#        ...,
#        [False, False, False, ...,  True,  True,  True],
#        [False, False, False, ..., False,  True,  True],
#        [False, False, False, ..., False, False,  True]])

# %%
mask = np.triu(np.ones_like(corr, dtype=np.bool)) # code explained in 'Concept of masking(during session).ipynb' file
fig = plt.subplots(figsize=(25, 15))
sns.heatmap(df_num.corr(), annot=True,fmt='.2f',mask=mask)
plt.show()

# %% [markdown]
# #### Observation
#
# There are considerable number of features that are highly correlated.
#
# - *'original_interest_rate'* shows high correlation with *'current_interest_rate','current_interest_rate_max','current_interest_rate_min'*
#
# - *'paid_interest* has high correlation with *'emi_dueamt','emi_received_amt'* etc.

# %% [markdown]
# ### Outlier Treatment

# %%
df_num.boxplot(figsize=(20,20))
plt.xticks(rotation=90)
plt.show()

# %%
no_outlier = ['age','current_interest_rate','current_interest_rate_max','current_interest_rate_min','net_ltv','orignal_interest_rate']

# %%
df_num[no_outlier].boxplot(figsize=(20,20))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# To treat outliers lets define a function **'treat_outlier'**.
#
# - For the higher outliers we will treat it to get it at 95 percentile value.
#
# - Lower level outliers will be treated to get it at 5 percentile value.

# %%
def treat_outlier(x):
    # taking 5,25,75 percentile of column
    q5= np.percentile(x,5)
    q25=np.percentile(x,25)
    q75=np.percentile(x,75)
    dt=np.percentile(x,95)
    #calculationg IQR range
    IQR=q75-q25
    #Calculating minimum threshold
    lower_bound=q25-(1.5*IQR)
    upper_bound=q75+(1.5*IQR)
    #Capping outliers
    return x.apply(lambda y: dt if y > upper_bound else y).apply(lambda y: q5 if y < lower_bound else y)

# %%
outlier_list = [x for x in df_num.columns if x not in no_outlier] # 'outlier_list' has all values in 'df_num.columns' except for those in 'no_outlier'

# %%
for i in df_num[outlier_list]:    
    df_num[i]=treat_outlier(df_num[i])

# %%
df_num.boxplot(figsize=(20,20))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## PCA

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2319 entries, 0 to 2318
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        2319 non-null   int64
#  1   gross_income               2319 non-null   float64
#  2   nettakehome                2319 non-null   float64
#  3   balance_tenure             2319 non-null   float64
#  4   completed_tenure           2319 non-null   float64
#  5   current_interest_rate      2319 non-null   float64
#  6   current_interest_rate_max  2319 non-null   float64
#  7   current_interest_rate_min  2319 non-null   float64
#  8   current_tenor              2319 non-null   float64
#  9   diff_emi_amount_max_min    2319 non-null   float64
#  10  emi_amount                 2319 non-null   float64
#  11  emi_dueamt                 2319 non-null   float64
#  12  emi_received_amt           2319 non-null   float64
#  13  excess_available           2319 non-null   float64
#  14  foir                       2319 non-null   float64
#  15  last_receipt_amount        2319 non-null   float64
#  16  loan_amt                   2319 non-null   float64
#  17  max_emi_amount             2319 non-null   float64
#  18  min_emi_amount             2319 non-null   float64
#  19  monthopening               2319 non-null   float64
#  20  net_disbursed_amt          2319 non-null   float64
#  21  net_ltv                    2319 non-null   float64
#  22  net_receivable             2319 non-null   float64
#  23  num_emi_changes            2319 non-null   float64
#  24  num_low_freq_transactions  2319 non-null   float64
#  25  num_of_emi_transactions    2319 non-null   float64
#  26  orignal_interest_rate      2319 non-null   float64
#  27  orignal_tenor              2319 non-null   float64
#  28  outstanding_principal      2319 non-null   float64
#  29  paid_interest              2319 non-null   float64
#  30  paid_principal             2319 non-null   float64
#  31  pre_emi_dueamt             2319 non-null   float64
#  32  pre_emi_received_amt       2319 non-null   float64
# dtypes: float64(32), int64(1)
# memory usage: 598.0 KB

# %%
from scipy.stats import zscore
df_num_scaled=df_num.apply(zscore)
df_num_scaled.head()
# Out:
#         age  gross_income  nettakehome  balance_tenure  completed_tenure  \
# 0 -0.050226     -0.239976    -0.220224       -0.885696          1.936521
# 1  1.286008      0.143740     0.158342       -0.983011          1.936521
# 2  0.172479     -0.398016    -0.376142       -2.077804          1.936521
# 3  0.283832     -0.004964     0.011633       -0.910025          1.936521
# 4 -1.386461     -0.224418    -0.204874       -0.861367          1.936521
#
#    current_interest_rate  current_interest_rate_max  \
# 0               0.951154                   0.925669
# 1              -0.382421                   0.925669
# 2               0.951154                   0.925669
# 3               0.951154                   0.925669
# 4               0.951154                   0.925669
#
#    current_interest_rate_min  current_tenor  diff_emi_amount_max_min  ...  \
# 0                   0.957515       0.183447                -0.487809  ...
# 1                  -0.374529       0.054735                -0.439942  ...
# 2                   0.957515      -1.639966                -0.437860  ...
# 3                   0.957515       0.161995                 0.166150  ...
# 4                   0.957515       0.183447                 0.018416  ...
#
#    num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 0         1.736155                   1.702129                 1.963788
# 1        -0.656620                   2.008377                 1.963788
# 2         2.334348                   1.702129                 1.963788
# 3         2.334348                   2.314625                 1.963788
# 4         2.334348                   1.702129                 1.963788
#
#    orignal_interest_rate  orignal_tenor  outstanding_principal  paid_interest  \
# 0               0.943596      -0.001359              -0.822279       0.727758
# 1               0.943596      -0.001359              -0.622608       1.042425
# 2               0.943596      -1.577073              -1.073859       0.486510
# 3               0.943596      -0.001359              -0.129192       2.556239
# 4               0.943596      -0.001359              -0.351567       1.709418
#
#    paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 0        0.033630       -0.135506             -0.128106
# 1        0.383527        0.388638              0.410165
# 2        2.661439       -0.163063             -0.156406
# 3        0.646972       -0.278420             -0.274871
# 4        0.402387       -0.053284             -0.043667
#
# [5 rows x 33 columns]

# %%
df_num_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2319 entries, 0 to 2318
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        2319 non-null   float64
#  1   gross_income               2319 non-null   float64
#  2   nettakehome                2319 non-null   float64
#  3   balance_tenure             2319 non-null   float64
#  4   completed_tenure           2319 non-null   float64
#  5   current_interest_rate      2319 non-null   float64
#  6   current_interest_rate_max  2319 non-null   float64
#  7   current_interest_rate_min  2319 non-null   float64
#  8   current_tenor              2319 non-null   float64
#  9   diff_emi_amount_max_min    2319 non-null   float64
#  10  emi_amount                 2319 non-null   float64
#  11  emi_dueamt                 2319 non-null   float64
#  12  emi_received_amt           2319 non-null   float64
#  13  excess_available           2319 non-null   float64
#  14  foir                       2319 non-null   float64
#  15  last_receipt_amount        2319 non-null   float64
#  16  loan_amt                   2319 non-null   float64
#  17  max_emi_amount             2319 non-null   float64
#  18  min_emi_amount             2319 non-null   float64
#  19  monthopening               2319 non-null   float64
#  20  net_disbursed_amt          2319 non-null   float64
#  21  net_ltv                    2319 non-null   float64
#  22  net_receivable             2319 non-null   float64
#  23  num_emi_changes            2319 non-null   float64
#  24  num_low_freq_transactions  2319 non-null   float64
#  25  num_of_emi_transactions    2319 non-null   float64
#  26  orignal_interest_rate      2319 non-null   float64
#  27  orignal_tenor              2319 non-null   float64
#  28  outstanding_principal      2319 non-null   float64
#  29  paid_interest              2319 non-null   float64
#  30  paid_principal             2319 non-null   float64
#  31  pre_emi_dueamt             2319 non-null   float64
#  32  pre_emi_received_amt       2319 non-null   float64
# dtypes: float64(33)
# memory usage: 598.0 KB

# %%
df_num_scaled.boxplot(figsize=(20,3))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Statistical tests to be done before PCA

# %% [markdown]
# #### Bartletts Test of Sphericity
# Bartlett's test of sphericity tests the hypothesis that the variables are uncorrelated in the population.
#
# - H0: All variables in the data are uncorrelated
# - Ha: At least one pair of variables in the data are correlated
#
# If the null hypothesis cannot be rejected, then PCA is not advisable.
#
# If the p-value is small, then we can reject the null hypothesis and agree that there is atleast one pair of vairbales in the data wihich are correlated hence PCA is recommended.

# %%
# Bartlett's Test of Sphericity 
# Compares an observed correlation matrix to the identity matrix
# it checks to see if there is a certain redundancy between the variables that we can summarize with a few number of factors
# Confirm the statistical significance of correlations

# H0: Correlations are not significant / Orthogonal / Not Correlated
# H1: There are significant correlations

# P low NULL Go!
# Reject H0 if p-value < 0.05

from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value,p_value=calculate_bartlett_sphericity(df_num_scaled)
p_value
# Out:
# 0.0

# %% [markdown]
# #### KMO Test
#
# The Kaiser-Meyer-Olkin (KMO) - measure of sampling adequacy (MSA) is an index used to examine how appropriate PCA is.
#
# Generally, if MSA is less than 0.5, PCA is not recommended, since no reduction is expected. On the other hand, MSA > 0.7 is expected to provide a considerable reduction is the dimension and extraction of meaningful components.

# %%
# Kaiser-Meyer-Olkin (KMO) Test 
# A measure of how suited your data is for Factor Analysis
# The test measures sampling adequacy for each variable in the model and for the complete model. 
# The statistic is a measure of the proportion of variance among variables that might be common variance.

# Confirm the adequacy of sample size. 
# Note: Above 0.7 is good, below 0.5 is not acceptable

from factor_analyzer.factor_analyzer import calculate_kmo
kmo_all,kmo_model=calculate_kmo(df_num_scaled)
kmo_model
# Out:
# 0.8184659398241245

# %% [markdown]
# ### Scree plot

# %%
# We can also get eigen values and eigen vectors manually from covariance matrix

# %%
# Step 1 - Create the Covariance Matrix

cov_matrix = np.cov(df_num_scaled.T)
print("Covaraince Matrix:\n\n", cov_matrix)
# Out:
# Covaraince Matrix:
#
#  [[ 1.00043141e+00  6.82469375e-02  5.91373829e-02 ...  1.55193039e-01
#    2.24303213e-02  2.12952078e-02]
#  [ 6.82469375e-02  1.00043141e+00  9.86919008e-01 ...  2.48283953e-01
#    9.61399124e-02  9.65661104e-02]
#  [ 5.91373829e-02  9.86919008e-01  1.00043141e+00 ...  2.33561145e-01
#    9.64727471e-02  9.68139716e-02]
#  ...
#  [ 1.55193039e-01  2.48283953e-01  2.33561145e-01 ...  1.00043141e+00
#   -1.26091479e-03  4.82686910e-04]
#  [ 2.24303213e-02  9.61399124e-02  9.64727471e-02 ... -1.26091479e-03
#    1.00043141e+00  9.99144872e-01]
#  [ 2.12952078e-02  9.65661104e-02  9.68139716e-02 ...  4.82686910e-04
#    9.99144872e-01  1.00043141e+00]]

# %%
# Step 2 - Get eigen values and eigen vector

# np.linalg.eig() function is not intended only for PCA. Hence, it would not return the values in Desc. order

eig_vals, eig_vect = np.linalg.eig(cov_matrix)

print("Eigen Values:\n\n",eig_vals)
print("\n")
print("Eigen Vector:\n\n",eig_vect)
# Out:
# Eigen Values:
#
#  [9.69740977e+00 5.00197114e+00 3.01796592e+00 2.68367518e+00
#  2.29590636e+00 1.79825376e+00 1.43162665e+00 1.21920245e+00
#  9.52738736e-01 8.73622357e-01 7.55147384e-01 6.87635584e-01
#  5.35198235e-01 4.94695623e-01 3.87739244e-01 3.12704688e-01
#  2.19341597e-01 1.67617835e-01 1.26064116e-01 1.12301425e-01
#  5.76323349e-02 4.45703524e-02 4.22547413e-02 3.66092941e-02
#  1.59395360e-02 1.41958195e-02 1.28574327e-02 8.77050107e-03
#  3.67083366e-03 3.38626441e-03 1.10635379e-03 1.24866186e-03
#  1.17622950e-03]
#
#
# Eigen Vector:
#
#  [[-0.02014627 -0.10092627 -0.09308731 ...  0.00128489 -0.00064779
#   -0.00157076]
#  [-0.21744871  0.03156662  0.10995023 ...  0.00331878  0.00273019
#    0.00243162]
#  [-0.21126924  0.03520226  0.1141955  ... -0.00118976 -0.00417298
#   -0.00189487]
#  ...
#  [-0.16040423 -0.11917057 -0.31399142 ...  0.00135349  0.00139797
#    0.00196157]
#  [-0.07290875  0.01209948  0.15403569 ... -0.42345655  0.56451727
#   -0.03113186]
#  [-0.07374132  0.01085759  0.15349051 ...  0.42787838 -0.5604992
#    0.02940949]]

# %%
tot = sum(eig_vals)

var_exp = [ (i/tot) * 100 for i in sorted(eig_vals, reverse = True)]
cum_var_exp = np.cumsum(var_exp)

print("Cumulative Variance Explained:\n",cum_var_exp )
# Out:
# Cumulative Variance Explained:
#  [ 29.37341833  44.52437043  53.66577802  61.79462021  68.74891207
#   74.19581607  78.5322079   82.22516763  85.11100974  87.75720863
#   90.04454726  92.1273929   93.74850638  95.24693759  96.42139833
#   97.36857967  98.03296456  98.54067836  98.9225261   99.2626867
#   99.43725483  99.57225826  99.70024772  99.81113714  99.85941793
#   99.90241702  99.94136213  99.96792795  99.97904689  99.98930387
#   99.99308606  99.99664886 100.        ]

# %%
var_exp
# Out:
# [29.37341833433889,
#  15.150952092352075,
#  9.141407597592982,
#  8.128842187651406,
#  6.954291860808394,
#  5.446904000287627,
#  4.33639183182685,
#  3.692959724290734,
#  2.885842108225518,
#  2.6461988877508125,
#  2.2873386345571793,
#  2.082845641080476,
#  1.621113475966129,
#  1.4984312138746099,
#  1.1744607354107421,
#  0.9471813441244505,
#  0.6643848869001971,
#  0.5077138014431332,
#  0.38184774208674366,
#  0.34016060161841244,
#  0.17456812926957457,
#  0.13500343259390385,
#  0.1279894551940054,
#  0.11088941646122473,
#  0.048280795708572806,
#  0.04299908475935267,
#  0.038945116072169945,
#  0.026565815313159758,
#  0.011118941594108983,
#  0.01025698237283579,
#  0.0037821921422210437,
#  0.0035627947932187123,
#  0.0033511415382533978]

# %%
tot = sum(eig_vals)

var_exp = [ (i/tot) * 100 for i in sorted(eig_vals, reverse = True)]
cum_var_exp = np.cumsum(var_exp)

print("Cumulative Variance Explained:\n",cum_var_exp )
# Out:
# Cumulative Variance Explained:
#  [ 29.37341833  44.52437043  53.66577802  61.79462021  68.74891207
#   74.19581607  78.5322079   82.22516763  85.11100974  87.75720863
#   90.04454726  92.1273929   93.74850638  95.24693759  96.42139833
#   97.36857967  98.03296456  98.54067836  98.9225261   99.2626867
#   99.43725483  99.57225826  99.70024772  99.81113714  99.85941793
#   99.90241702  99.94136213  99.96792795  99.97904689  99.98930387
#   99.99308606  99.99664886 100.        ]

# %%
# Step 4 Apply PCA for the number of decided components to get the loadings and component output

# Using scikit learn PCA here. It does all the above steps and maps data to PCA dimensions in one shot
from sklearn.decomposition import PCA
# NOTE - we are generating only 8 PCA dimensions (dimensionality reduction from 33 to 8)
pca = PCA(n_components=8, random_state=123)
df_pca = pca.fit_transform(df_num_scaled)
df_pca.transpose() # Component output
# Out:
# array([[ 0.13832827,  0.63205268,  1.03854778, ..., -3.01724891,
#         -1.64731774, -3.02498793],
#        [-3.94762052, -2.86568024, -5.89017883, ...,  0.43477001,
#          0.81296655,  0.28690108],
#        [ 0.01130851,  1.10242534,  1.81830086, ..., -0.65943335,
#          0.07570841,  2.90274012],
#        ...,
#        [ 0.31988377,  1.56775814,  0.26753095, ..., -0.7899804 ,
#         -0.97943608,  0.15714945],
#        [ 0.41604043,  0.42580728,  1.84692677, ..., -0.14617257,
#          2.29148091,  0.1073373 ],
#        [ 0.35617767,  0.46735294, -0.44765723, ..., -0.56497181,
#         -1.44013059, -0.73519749]])

# %%
# Loading of each feature on the components
pca.components_
# Out:
# array([[ 0.02014627,  0.21744871,  0.21126924, -0.0696896 ,  0.09099176,
#          0.14926688,  0.15673719,  0.14735309, -0.04142426,  0.1861108 ,
#          0.28038238,  0.27788661,  0.26814394,  0.04890196,  0.1088314 ,
#          0.24039174,  0.2747473 ,  0.19577635,  0.03243448,  0.26460352,
#          0.2758785 ,  0.06065134,  0.07522952,  0.07326248,  0.09978476,
#          0.0897586 ,  0.15498928, -0.0390214 ,  0.24156068,  0.27527696,
#          0.16040423,  0.07290875,  0.07374132],
#        [-0.10092627,  0.03156662,  0.03520226,  0.30832747, -0.25207128,
#         -0.26882099, -0.27394218, -0.27009789,  0.24468839,  0.03629618,
#          0.12110679, -0.06101158, -0.06074546, -0.05459196,  0.16142978,
#          0.08689961,  0.20563687,  0.04244355, -0.00929268,  0.22731124,
#          0.2038083 ,  0.19699083, -0.05478914, -0.12362715, -0.14533296,
#         -0.2591793 , -0.27467176,  0.23807634,  0.24167031, -0.03294935,
#         -0.11917058,  0.01209948,  0.01085759],
#        [ 0.09308731, -0.10995023, -0.1141955 , -0.25031167,  0.21682763,
#         -0.33815863, -0.31989278, -0.33801883, -0.21166844,  0.17333474,
#         -0.0054996 ,  0.13294652,  0.14287606,  0.20580392,  0.06381638,
#          0.04963689, -0.01702216,  0.15762118, -0.07007699, -0.04610587,
#         -0.01368112,  0.08864135, -0.03098785,  0.01272764,  0.0846492 ,
#          0.18340232, -0.32210155, -0.13245386, -0.09736534,  0.07033631,
#          0.31399141, -0.15403569, -0.15349051],
#        [-0.18679074, -0.17104571, -0.17258002,  0.25005644,  0.2803619 ,
#         -0.0447442 , -0.03730312, -0.04537343,  0.36305309, -0.00813732,
#         -0.07666759,  0.1253379 ,  0.11474344, -0.03683144,  0.01536361,
#         -0.06456988, -0.0557539 , -0.02574935, -0.12685175, -0.04928581,
#         -0.05355166,  0.01857394,  0.17960185,  0.33997332,  0.31082507,
#          0.33070266, -0.0385675 ,  0.34176627, -0.01154524,  0.16854266,
#         -0.11409845,  0.15476179,  0.15483884],
#        [ 0.11412014, -0.02842236, -0.02422869, -0.07372178, -0.26505727,
#         -0.04456534, -0.05526574, -0.04311036, -0.17176061,  0.20737094,
#         -0.02025768, -0.17814088, -0.19122849,  0.14989488,  0.05389477,
#          0.07857642, -0.00957089,  0.19177356, -0.14865305, -0.00385069,
#         -0.01264137, -0.08284534,  0.09122374,  0.34929041,  0.16711551,
#         -0.15032736, -0.05282775, -0.15977095, -0.02656185, -0.14828087,
#          0.01962999,  0.4650858 ,  0.46440461],
#        [ 0.15677613, -0.02734854, -0.03031212, -0.11010697,  0.09334501,
#         -0.10815382, -0.0922795 , -0.10767469, -0.10887392, -0.3850238 ,
#          0.08272263,  0.11442913,  0.15686809, -0.28421319,  0.10595388,
#         -0.11427803,  0.04659389, -0.37258158,  0.08110752,  0.02490046,
#          0.04736651, -0.06269446, -0.21370253, -0.08730813, -0.2306898 ,
#          0.16966805, -0.09005198, -0.14647036,  0.07303174,  0.16927604,
#          0.01675916,  0.35845824,  0.35975744],
#        [ 0.1993246 ,  0.24386022,  0.24684654, -0.05752342, -0.0255976 ,
#         -0.07670035, -0.10237328, -0.07429424, -0.09634476, -0.19168488,
#          0.01765127,  0.01454226, -0.03711519, -0.34982559, -0.09730406,
#         -0.07181186,  0.03132677, -0.21072397, -0.27738577,  0.03509517,
#          0.0326799 ,  0.10439934,  0.44530333,  0.19160041,  0.31997212,
#         -0.05340253, -0.10325758, -0.21015614,  0.10069083, -0.06155538,
#         -0.17386699, -0.16379388, -0.16586628],
#        [-0.14536962,  0.46892676,  0.47802966,  0.03883674,  0.06303943,
#         -0.10819744, -0.09770403, -0.10858192,  0.08544988, -0.00303535,
#         -0.07861302, -0.00383206,  0.00825021,  0.20381309, -0.52809757,
#         -0.0803788 , -0.04467881, -0.00106602, -0.02326682, -0.04535467,
#         -0.04373123, -0.17070282, -0.18232222,  0.00722682, -0.05984784,
#          0.08595836, -0.09687004,  0.14706507, -0.08653239,  0.02100145,
#          0.09538287,  0.10773562,  0.10917514]])

# %%
var_exp = pca.explained_variance_ratio_

# %%
#Check the explained variance for each PC
#Note: Explained variance = (eigen value of each PC)/(sum of eigen values of all PCs)
pca.explained_variance_ratio_
# Out:
# array([0.29373418, 0.15150952, 0.09141408, 0.08128842, 0.06954292,
#        0.05446904, 0.04336392, 0.0369296 ])

# %% [markdown]
# Let's create a dataframe of component loading against each field and identify the pattern

# %%
# Step 3 View Scree Plot to identify the number of components to be built
plt.figure(figsize=(12,7))
sns.lineplot(y=var_exp,x=range(1,len(var_exp)+1),marker='o')
plt.xlabel('Number of Components',fontsize=15)
plt.ylabel('Variance Explained',fontsize=15)
plt.title('Scree Plot',fontsize=15)
plt.grid()
plt.show()

# %%
df_pca_loading = pd.DataFrame(pca.components_,columns=list(df_num_scaled))
df_pca_loading.shape
# Out:
# (8, 33)

# %%
df_pca_loading.head(8)
# Out:
#         age  gross_income  nettakehome  balance_tenure  completed_tenure  \
# 0  0.020146      0.217449     0.211269       -0.069690          0.090992
# 1 -0.100926      0.031567     0.035202        0.308327         -0.252071
# 2  0.093087     -0.109950    -0.114196       -0.250312          0.216828
# 3 -0.186791     -0.171046    -0.172580        0.250056          0.280362
# 4  0.114120     -0.028422    -0.024229       -0.073722         -0.265057
# 5  0.156776     -0.027349    -0.030312       -0.110107          0.093345
# 6  0.199325      0.243860     0.246847       -0.057523         -0.025598
# 7 -0.145370      0.468927     0.478030        0.038837          0.063039
#
#    current_interest_rate  current_interest_rate_max  \
# 0               0.149267                   0.156737
# 1              -0.268821                  -0.273942
# 2              -0.338159                  -0.319893
# 3              -0.044744                  -0.037303
# 4              -0.044565                  -0.055266
# 5              -0.108154                  -0.092280
# 6              -0.076700                  -0.102373
# 7              -0.108197                  -0.097704
#
#    current_interest_rate_min  current_tenor  diff_emi_amount_max_min  ...  \
# 0                   0.147353      -0.041424                 0.186111  ...
# 1                  -0.270098       0.244688                 0.036296  ...
# 2                  -0.338019      -0.211668                 0.173335  ...
# 3                  -0.045373       0.363053                -0.008137  ...
# 4                  -0.043110      -0.171761                 0.207371  ...
# 5                  -0.107675      -0.108874                -0.385024  ...
# 6                  -0.074294      -0.096345                -0.191685  ...
# 7                  -0.108582       0.085450                -0.003035  ...
#
#    num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 0         0.073262                   0.099785                 0.089759
# 1        -0.123627                  -0.145333                -0.259179
# 2         0.012728                   0.084649                 0.183402
# 3         0.339973                   0.310825                 0.330703
# 4         0.349290                   0.167116                -0.150327
# 5        -0.087308                  -0.230690                 0.169668
# 6         0.191600                   0.319972                -0.053403
# 7         0.007227                  -0.059848                 0.085958
#
#    orignal_interest_rate  orignal_tenor  outstanding_principal  paid_interest  \
# 0               0.154989      -0.039021               0.241561       0.275277
# 1              -0.274672       0.238076               0.241670      -0.032949
# 2              -0.322102      -0.132454              -0.097365       0.070336
# 3              -0.038568       0.341766              -0.011545       0.168543
# 4              -0.052828      -0.159771              -0.026562      -0.148281
# 5              -0.090052      -0.146470               0.073032       0.169276
# 6              -0.103258      -0.210156               0.100691      -0.061555
# 7              -0.096870       0.147065              -0.086532       0.021001
#
#    paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 0        0.160404        0.072909              0.073741
# 1       -0.119171        0.012099              0.010858
# 2        0.313991       -0.154036             -0.153491
# 3       -0.114098        0.154762              0.154839
# 4        0.019630        0.465086              0.464405
# 5        0.016759        0.358458              0.359757
# 6       -0.173867       -0.163794             -0.165866
# 7        0.095383        0.107736              0.109175
#
# [8 rows x 33 columns]

# %% [markdown]
# Let's identify which features have maximum loading across the components.
#
# - We will first plot the component loading on a heatmap.
#
# - For each feature, we find the maximum loading value across the components and mark the same with help of rectangular box.
#
# - Features marked with rectangular red box are the one having maximum loading on the respective component. We consider these marked features to decide the context that the component represents

# %%
from matplotlib.patches import Rectangle

# %%
## BY SIR:
# Define the "characterstics of PCs"

# df_pca = is the fit transformed state of the Pronciple components
# we no longer are looking to the original 33 features and need to think in terms of Princple components 
# remember the way we need to visualize the principle components (refer to the excel workbook and sheet "concepts" )

# we have formed the df_pca with 8 columns that covers 82% of the information
# each PCA contains the properteries / information of all the 33 columns, but at a different loading level.

# look through the loading along side the X axis in the above plot against each Principle components 
# eg: PC0
#     loading is visible for the columns such as emi_amount, emi_due_amount, emi_received_amount, latest_receipt_amount, 
#     loan_amount, monthopening and net_disbursement_amount
#
#  A subject matter expert can help to infer based onthis loading that PC0 has to do with Loan Repayment 
#
# Similarly for PC5
#     Loading is visible for the columns diff_emi_amount_max_min, max_emi_amount
#
# A subject matter expert can help to infer based onthis loading that PC5 has to do with emi and,
# and those coloumns are related to Pre_emi from a business perspective.

# making business knoledge based inferences on PCs is an additional effort and needs subject matter experts.


# Principle component columns ['PC0','PC1','PC2','PC3','PC4','PC5','PC6','PC7'] are renamed 
# based on what it represents / defrines the the most
# Rember: This step would require the help of a subject matter expert (in most of the cases)


fig,ax = plt.subplots(figsize=(22, 10), facecolor='w', edgecolor='k')
ax = sns.heatmap(df_pca_loading, annot=True, vmax=1.0, vmin=0, cmap='Blues', cbar=False, fmt='.2g', ax=ax,
                 yticklabels=['PC0','PC1','PC2','PC3','PC4','PC5','PC6','PC7'])

column_max = df_pca_loading.abs().idxmax(axis=0)

for col, variable in enumerate(df_pca_loading.columns):
    position = df_pca_loading.index.get_loc(column_max[variable])
    ax.add_patch(Rectangle((col, position),1,1, fill=False, edgecolor='red', lw=3))

# %%
df_pca = pd.DataFrame(df_pca,columns=['pc_loan_repayment','pc_balance_loan','pc_interest_rate','pc_tenure',
                                  'pc_pre_emi','pc_emi','pc_receiveable','pc_income'])
df_pca.head()
# Out:
#    pc_loan_repayment  pc_balance_loan  pc_interest_rate  pc_tenure  \
# 0           0.138328        -3.947621          0.011309   2.544589
# 1           0.632053        -2.865680          1.102425   1.706172
# 2           1.038548        -5.890179          1.818301   1.498773
# 3           3.693353        -3.578944          1.087235   3.726671
# 4           2.381332        -3.702655          0.854477   3.617402
#
#    pc_pre_emi    pc_emi  pc_receiveable  pc_income
# 0   -0.750891  0.319884        0.416040   0.356178
# 1   -0.894925  1.567758        0.425807   0.467353
# 2    0.398085  0.267531        1.846927  -0.447657
# 3   -1.030339 -0.074850        1.874251  -0.645492
# 4   -0.320202 -1.041227        0.328920   0.257505

# %%
df_pca.shape
# Out:
# (2319, 8)

# %% [markdown]
# ### EDA (Categorical Fields & Principal Components)

# %%
df_new = pd.concat([df_cat, df_pca], axis=1)

# %%
df_new.shape
# Out:
# (2319, 13)

# %%
df_new.head()
# Out:
#   loan_account gender marital_status qualification     city  \
# 0        LA492      F              M            UG  MADURAI
# 1        LA498      M              M          GRAD  MADURAI
# 2        LA500      M              M            UG  MADURAI
# 3        LA531      M              M            UG  MADURAI
# 4        LA552      M              S          GRAD  MADURAI
#
#    pc_loan_repayment  pc_balance_loan  pc_interest_rate  pc_tenure  \
# 0           0.138328        -3.947621          0.011309   2.544589
# 1           0.632053        -2.865680          1.102425   1.706172
# 2           1.038548        -5.890179          1.818301   1.498773
# 3           3.693353        -3.578944          1.087235   3.726671
# 4           2.381332        -3.702655          0.854477   3.617402
#
#    pc_pre_emi    pc_emi  pc_receiveable  pc_income
# 0   -0.750891  0.319884        0.416040   0.356178
# 1   -0.894925  1.567758        0.425807   0.467353
# 2    0.398085  0.267531        1.846927  -0.447657
# 3   -1.030339 -0.074850        1.874251  -0.645492
# 4   -0.320202 -1.041227        0.328920   0.257505

# %%
df_new.describe(include='all')
# Out:
#        loan_account gender marital_status qualification    city  \
# count          2319   2319           2319          2319    2319
# unique         2319      2              2             8      17
# top           LA646      M              M            UG  MUMBAI
# freq              1   1994           2086          1548     607
# mean            NaN    NaN            NaN           NaN     NaN
# std             NaN    NaN            NaN           NaN     NaN
# min             NaN    NaN            NaN           NaN     NaN
# 25%             NaN    NaN            NaN           NaN     NaN
# 50%             NaN    NaN            NaN           NaN     NaN
# 75%             NaN    NaN            NaN           NaN     NaN
# max             NaN    NaN            NaN           NaN     NaN
#
#         pc_loan_repayment  pc_balance_loan  pc_interest_rate     pc_tenure  \
# count        2.319000e+03     2.319000e+03      2.319000e+03  2.319000e+03
# unique                NaN              NaN               NaN           NaN
# top                   NaN              NaN               NaN           NaN
# freq                  NaN              NaN               NaN           NaN
# mean         1.895853e-17    -1.175333e-17      1.060912e-16 -5.113058e-17
# std          3.114066e+00     2.236509e+00      1.737229e+00  1.638193e+00
# min         -5.761975e+00    -5.973697e+00     -5.116932e+00 -5.280734e+00
# 25%         -2.267257e+00    -1.629814e+00     -1.166888e+00 -1.135981e+00
# 50%         -6.419539e-01    -4.371668e-02     -1.152916e-01  4.656669e-02
# 75%          1.617456e+00     1.609900e+00      1.102363e+00  1.122729e+00
# max          1.069492e+01     6.971915e+00      5.732810e+00  5.346676e+00
#
#           pc_pre_emi        pc_emi  pc_receiveable     pc_income
# count   2.319000e+03  2.319000e+03    2.319000e+03  2.319000e+03
# unique           NaN           NaN             NaN           NaN
# top              NaN           NaN             NaN           NaN
# freq             NaN           NaN             NaN           NaN
# mean    1.481734e-16 -1.173897e-16   -2.744140e-16  1.334757e-16
# std     1.515225e+00  1.340990e+00    1.196506e+00  1.104175e+00
# min    -4.500180e+00 -4.743138e+00   -4.100491e+00 -3.840107e+00
# 25%    -9.898574e-01 -7.175728e-01   -7.414753e-01 -7.200439e-01
# 50%    -2.549250e-01  5.489084e-02   -1.985178e-02 -6.199159e-02
# 75%     7.689656e-01  7.605432e-01    7.320117e-01  6.150100e-01
# max     5.802258e+00  4.797039e+00    4.250443e+00  5.003263e+00

# %%
fig,ax = plt.subplots(figsize=(22,7))
sns.boxplot(x='city',y='pc_loan_repayment', data=df_new)
# Out:
# <AxesSubplot:xlabel='city', ylabel='pc_loan_repayment'>

# %% [markdown]
# From above plots we observe that for Ahmedabad & Surat the loan repayment amount is comparatively lower than other cities.
#
# Loan repayment amount is highest for Chennai compared to other cities

# %%
fig,ax = plt.subplots(figsize=(22,7))
sns.boxplot(x='city',y='pc_interest_rate', data=df_new)
# Out:
# <AxesSubplot:xlabel='city', ylabel='pc_interest_rate'>

# %% [markdown]
# Interest rate is highest for Ahmedabad and lowest for Tirupur

# %%
fig,ax = plt.subplots(figsize=(22,7))
sns.boxplot(x='city',y='pc_pre_emi', data=df_new)
# Out:
# <AxesSubplot:xlabel='city', ylabel='pc_pre_emi'>

# %% [markdown]
# City of Erode seems to have highest pre-emi payments

# %% [markdown]
# #### Observation
#
# - From above plots we observe that for Ahmedabad city, loan repayment amount is comparatively lower than other cities however, the interest rate charged to the customers is much higher
#
# - For Erode city, loan repayment amount is low, interest rate is comparative high and the pre-emi amount paid by customers from this city is also high

# %% [markdown]
# ### Apply rules & analyze patterns in data

# %% [markdown]
# #### Case 1 - Advance Closure
# Customer who
# - has to pay lesser loan,
# - has done some payment as part of pre-emi and
# - has an high income
# have higher chances to do *advance payment* and close the loan in advance thus causing loss to the financial institute
#
# Let's create a subset dataframe *df_adv_closure* which satisfies all above conditions and analyze it further

# %%
cond1 = df_new.pc_loan_repayment < df_new.pc_loan_repayment.quantile(0.25) # customers paying lesser loan
cond2 = df_new.pc_pre_emi > df_new.pc_pre_emi.quantile(0.75) # customers who have paid high pre-emi
cond3 = df_new.pc_income > df_new.pc_income.quantile(0.75) # customers who have high income
df_adv_closure = df_new[cond1 & cond2 & cond3] # Find customers satisifying all above conditions

# %%
df_adv_closure.index
# Out:
# Int64Index([ 251,  915, 1057, 1148, 1216, 1247, 1408, 1414, 1428, 1486, 1495,
#             1496, 1661, 1747, 1782, 1800, 1834, 1840, 1846, 1871, 1899, 2002,
#             2032, 2141, 2147, 2163, 2240, 2304],
#            dtype='int64')

# %% [markdown]
# Above index corresponds to the rows or loan accounts which satisfy the Case 1 conditions. Let's create a new field 'advance_closure' which will hold a value of 1 for above indexed rows

# %%
df_adv_closure=df_adv_closure.assign(advance_closure=1)
df_adv_closure.head()
# Out:
#      loan_account gender marital_status qualification       city  \
# 251        LA1321      M              S          GRAD  TUTICORIN
# 915        LA2868      M              M          GRAD    MADURAI
# 1057       LA3138      M              M            UG      SURAT
# 1148       LA3318      M              M            UG    CHENNAI
# 1216       LA3439      M              M            UG     MUMBAI
#
#       pc_loan_repayment  pc_balance_loan  pc_interest_rate  pc_tenure  \
# 251           -3.236127        -0.631951         -1.971316   3.640110
# 915           -2.538345         0.845063          0.497815   3.415984
# 1057          -2.555448         0.845925         -1.644663   2.893056
# 1148          -2.859567        -2.188669          3.055199  -1.523749
# 1216          -3.061674         1.792790          5.466580   0.712567
#
#       pc_pre_emi    pc_emi  pc_receiveable  pc_income  advance_closure
# 251     1.585632  1.882636       -2.349836   1.334191                1
# 915     1.119821 -0.473038       -0.596415   2.228886                1
# 1057    2.068014  1.878371       -1.452161   0.620491                1
# 1148    1.014246  0.435528        0.809753   1.142229                1
# 1216    1.464098 -2.744298       -1.641138   0.970271                1

# %% [markdown]
# Let's merge *advance_closure* field with our original dataframe for the selected index and analyze further

# %%
df_merge = df.merge(df_adv_closure['advance_closure'],left_on=df.index, right_index=True, 
                    right_on=df_adv_closure.index, how='left')
df_merge.head(252)
# Out:
#     loan_account  age gender marital_status qualification   gross_income  \
# 0          LA492   39      F              M            UG   63542.344735
# 1          LA498   51      M              M          GRAD   81130.025032
# 2          LA500   41      M              M            UG   56298.592500
# 3          LA531   42      M              M            UG   74314.142100
# 4          LA552   27      M              S          GRAD   64255.460240
# ..           ...  ...    ...            ...           ...            ...
# 247       LA1309   44      M              M            UG   91110.639510
# 248       LA1310   24      M              S          GRAD  150129.580000
# 249       LA1317   40      F              M        OTHERS   47290.817700
# 250       LA1319   33      M              M            UG   78067.381600
# 251       LA1321   24      M              S          GRAD   26422.806080
#
#        nettakehome  balance_tenure       city  completed_tenure  ...  \
# 0     63542.344735             111    MADURAI                70  ...
# 1     81130.025032             107    MADURAI                68  ...
# 2     56298.592500              50    MADURAI                70  ...
# 3     74314.142100             110    MADURAI                70  ...
# 4     64255.460240             112    MADURAI                69  ...
# ..             ...             ...        ...               ...  ...
# 247   91110.639510             164     MUMBAI                51  ...
# 248  150129.580000             123    CHENNAI                57  ...
# 249   47290.817700             128     MUMBAI                52  ...
# 250   78067.381600              36  TUTICORIN                51  ...
# 251   26422.806080             204  TUTICORIN                37  ...
#
#      num_low_freq_transactions  num_of_emi_transactions  \
# 0                           10                       73
# 1                           11                       73
# 2                           10                       73
# 3                           17                       72
# 4                           10                       71
# ..                         ...                      ...
# 247                          7                       52
# 248                          9                       58
# 249                          9                       53
# 250                          1                       54
# 251                          2                       52
#
#      orignal_interest_rate  orignal_tenor  outstanding_principal  \
# 0                17.479728            180           9.882910e+05
# 1                17.479728            180           1.206218e+06
# 2                17.479728            120           7.137100e+05
# 3                17.479728            180           1.744746e+06
# 4                17.479728            180           1.502039e+06
# ..                     ...            ...                    ...
# 247              17.479728            180           3.142253e+06
# 248              18.104004            180           3.691821e+06
# 249              17.479728            180           9.093694e+05
# 250              17.479728            120           3.683910e+05
# 251              15.606900            240           6.829064e+05
#
#      paid_interest  paid_principal  pre_emi_dueamt  pre_emi_received_amt  \
# 0     9.340537e+05   212745.625226    39959.331336          39959.331336
# 1     1.069305e+06   295078.188194    78774.632736          78774.632736
# 2     8.303592e+05   487326.621863    37918.629288          37918.629288
# 3     1.567354e+06   357068.193072    29375.950152          29375.950152
# 4     1.355995e+06   299516.018579    46048.309200          46048.309200
# ..             ...             ...             ...                   ...
# 247   9.194536e+04    10468.535613    27054.762000          27054.762000
# 248   2.674090e+06   511806.751178    42344.567496          42344.567496
# 249   1.915338e+05    28940.479137    11811.336096          11811.336096
# 250   3.669107e+05   457321.724004    29758.029648          29758.029648
# 251   3.619744e+05    30209.074088   135916.498632         135916.498632
#
#      advance_closure
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 247              NaN
# 248              NaN
# 249              NaN
# 250              NaN
# 251              1.0
#
# [252 rows x 39 columns]

# %%
df_merge.advance_closure.fillna(0, inplace=True)

# %%
df_merge.advance_closure.value_counts()
# Out:
# 0.0    2291
# 1.0      28
# Name: advance_closure, dtype: int64

# %% [markdown]
# #### Analyze data for probable customers who may payoff the loan in advance

# %%
sns.boxplot(df_merge.advance_closure, df_merge.num_emi_changes)
# Out:
# <AxesSubplot:xlabel='advance_closure', ylabel='num_emi_changes'>

# %%
sns.boxplot(df_merge.advance_closure, df_merge.outstanding_principal)
# Out:
# <AxesSubplot:xlabel='advance_closure', ylabel='outstanding_principal'>

# %%
sns.boxplot(df_merge.advance_closure, df_merge.paid_interest)
# Out:
# <AxesSubplot:xlabel='advance_closure', ylabel='paid_interest'>

# %% [markdown]
# #### Observation:
#
# 28 customers have low outstanding principal, have paid less interest so far and we also see that there are more changes in emi value being paid. Hence, there is high probability that these customers may close the loans in advance

# %% [markdown]
# #### Case 2 - Loan Default:
#
# Customers
# - with high loan,
# - low income and
# - high loan interest rate
# are probable customers to default.
#
# Let's create a subset dataframe *df_delay_closure* which satisfies all above conditions and analyze further

# %%
cond1 = df_new.pc_loan_repayment > df_new.pc_loan_repayment.quantile(0.75)# customers paying higher loan
cond2 = df_new.pc_income < df_new.pc_income.quantile(0.25) # customers with lesser income
cond3 = df_new.pc_interest_rate > df_new.pc_interest_rate.quantile(0.75) # customers paying higher interest

df_delay_closure = df_new[cond1 & cond2 & cond3]# Find customers satisifying all above conditions

# %%
df_delay_closure.index

# %% [markdown]
# Above index corresponds to the rows or loan accounts which satisfy the Case 2 conditions. Let's create a new field *'delay_closure'* which will hold a value of 1 for above indexed rows

# %%
df_delay_closure = df_delay_closure.assign(delay_closure=1)
df_delay_closure.head()

# %% [markdown]
# Let's merge the *df_delay_closure* with original dataframe *'df'* and just add the *'delay_closure'* field

# %%
df_merge = df.merge(df_delay_closure['delay_closure'],left_on=df.index, right_index=True, 
                    right_on=df_delay_closure.index, how='left')
df_merge.head(79)

# %%
df_merge['delay_closure'].fillna(0, inplace=True)

# %%
df_merge.delay_closure.value_counts()

# %% [markdown]
# #### Analyze data for probable customers who may default

# %%
sns.boxplot(df_merge.delay_closure, df_merge.net_ltv)

# %%
sns.boxplot(df_merge.delay_closure, df_merge.outstanding_principal)

# %%
sns.boxplot(df_merge.delay_closure, df_merge.paid_interest)

# %% [markdown]
# #### Observation:

# %% [markdown]
# ### Conclusion
